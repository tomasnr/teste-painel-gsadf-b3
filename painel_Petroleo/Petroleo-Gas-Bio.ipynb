# %%
### SCRIPT PARA OBTER HISTORICO DE COTACAO DAS ACOES B3.
#
### ATE 15/09/2022 (site B3) 482 EMPRESAS COM ACOES NEGOCIAVEIS NO MERCADO A VISTA.
#
### CRITERIO DE SELECAO DOS TICKERS NEGOCIAVEIS.
### ATIVOS PERTENCENTES AOS SEGUIMENTOS NOVO MERCADO (NM),
### CIA. NIVEL 1 E 2 DE GOVERNANCA CORPORATIVA (N1 E N2),
### TRADICIONAL-BOLSA (EXCLUINDO DRE), BOVESPA MAIS (MA)
### E BOVESPA MAIS NIVEL 2 (M2).
 
###########################################################
# ROTINA PARA IMPORTAR O HISTORICO DE COTACAO DOS TICKERS #
###########################################################

# INSTALAR O YAHOO QUERY

# !pip install yahooquery

# (SE NECESSARIO) INSTALAR LEITOR DE ARQUIVO XLS

# !pip install xlrd

# INICIALIZAR OS MODULOS YAHOOQUERY

import yahooquery as yq
from yahooquery import Ticker

# INICIALIZAR OS MODULOS AUXILIARES

import pandas as pd
import requests as rq
import numpy as ny

###########################################################
# IMPORTAR HISTORICO DE COTACAO DOS ATIVOS SELECIONADOS   #
# OS CODIGOS SERAO DIVIDIDOS POR SETOR ECONOMICO          #
###########################################################

# %%
### 1 ###
###########################################################
### SETOR ECONOMICO: PETROLEO, GAS E BIOCOMBUSTIVEL     ###
###########################################################

# 3R PETROLEUM
RRRP3 = Ticker('RRRP3.SA')
hist_RRRP3 = RRRP3.history(period='60d', interval='5m')
ativo_RRRP3 = pd.DataFrame(hist_RRRP3)
RRRP3_close = ativo_RRRP3['close']
RRRP3_close.to_excel('RRRP3_close.xlsx')

# COSAN
CSAN3 = Ticker('CSAN3.SA')
hist_CSAN3 = CSAN3.history(period='60d', interval='5m')
ativo_CSAN3 = pd.DataFrame(hist_CSAN3)
CSAN3_close = ativo_CSAN3['close']
CSAN3_close.to_excel('CSAN3_close.xlsx')

# DOMMO
DMMO3 = Ticker('DMMO3.SA')
hist_DMMO3 = DMMO3.history(period='60d', interval='5m')
ativo_DMMO3 = pd.DataFrame(hist_DMMO3)
DMMO3_close = ativo_DMMO3['close']
DMMO3_close.to_excel('DMMO3_close.xlsx')

# ENAUTA PART
ENAT3 = Ticker('ENAT3.SA')
hist_ENAT3 = ENAT3.history(period='60d', interval='5m')
ativo_ENAT3 = pd.DataFrame(hist_ENAT3)
ENAT3_close = ativo_ENAT3['close']
ENAT3_close.to_excel('ENAT3_close.xlsx')

# PET MANGUINH
RPMG3 = Ticker('RPMG3.SA')
hist_RPMG3 = RPMG3.history(period='60d', interval='5m')
ativo_RPMG3 = pd.DataFrame(hist_RPMG3)
RPMG3_close = ativo_RPMG3['close']
RPMG3_close.to_excel('RPMG3_close.xlsx')

# %%
# PETROBRAS   
PETR3 = Ticker('PETR3.SA')
hist_PETR3 = PETR3.history(period='60d', interval='5m')
ativo_PETR3 = pd.DataFrame(hist_PETR3)
PETR3_close = ativo_PETR3['close']
PETR3_close.to_excel('PETR3_close.xlsx')

PETR4 = Ticker('PETR4.SA')
hist_PETR4 = PETR4.history(period='60d', interval='5m')
ativo_PETR4 = pd.DataFrame(hist_PETR4)
PETR4_close = ativo_PETR4['close']
PETR4_close.to_excel('PETR4_close.xlsx')

# PETRORECSA 
RECV3 = Ticker('RECV3.SA')
hist_RECV3 = RECV3.history(period='60d', interval='5m')
ativo_RECV3 = pd.DataFrame(hist_RECV3)
RECV3_close = ativo_RECV3['close']
RECV3_close.to_excel('RECV3_close.xlsx')

# PETRORIO
PRIO3 = Ticker('PRIO3.SA')
hist_PRIO3 = PRIO3.history(period='60d', interval='5m')
ativo_PRIO3 = pd.DataFrame(hist_PRIO3)
PRIO3_close = ativo_PRIO3['close']
PRIO3_close.to_excel('PRIO3_close.xlsx')

# ULTRAPAR    
UGPA3 = Ticker('UGPA3.SA')
hist_UGPA3 = UGPA3.history(period='60d', interval='5m')
ativo_UGPA3 = pd.DataFrame(hist_UGPA3)
UGPA3_close = ativo_UGPA3['close']
UGPA3_close.to_excel('UGPA3_close.xlsx')

# %%
# VIBRA
VBBR3 = Ticker('VBBR3.SA')
hist_VBBR3 = VBBR3.history(period='60d', interval='5m')
ativo_VBBR3 = pd.DataFrame(hist_VBBR3)
VBBR3_close = ativo_VBBR3['close']
VBBR3_close.to_excel('VBBR3_close.xlsx')

# LUPATECH    
LUPA3 = Ticker('LUPA3.SA')
hist_LUPA3 = LUPA3.history(period='60d', interval='5m')
ativo_LUPA3 = pd.DataFrame(hist_LUPA3)
LUPA3_close = ativo_LUPA3['close']
LUPA3_close.to_excel('LUPA3_close.xlsx')

# OCEANPACT
OPCT3 = Ticker('OPCT3.SA')
hist_OPCT3 = OPCT3.history(period='60d', interval='5m')
ativo_OPCT3 = pd.DataFrame(hist_OPCT3)
OPCT3_close = ativo_OPCT3['close']
OPCT3_close.to_excel('OPCT3_close.xlsx')

# OSX BRASIL  # ACHO QUE ESSA NAO TEM NEGOCIACAO
OSXB3 = Ticker('OSXB3.SA')
hist_OSXB3 = OSXB3.history(period='60d', interval='5m')
ativo_OSXB3 = pd.DataFrame(hist_OSXB3)
OSXB3_close = ativo_OSXB3['close']
OSXB3_close.to_excel('OSXB3_close.xlsx')
