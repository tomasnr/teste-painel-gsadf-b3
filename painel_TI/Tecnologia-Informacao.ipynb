# %%
### SCRIPT PARA OBTER HISTORICO DE COTACAO DAS ACOES B3.
#
### ATE 15/09/2022 (site B3) 482 EMPRESAS COM ACOES NEGOCIAVEIS NO MERCADO A VISTA.
#
### CRITERIO DE SELECAO DOS TICKERS NEGOCIAVEIS.
### ATIVOS PERTENCENTES AOS SEGUIMENTOS NOVO MERCADO (NM),
### CIA. NIVEL 1 E 2 DE GOVERNANCA CORPORATIVA (N1 E N2),
### TRADICIONAL-BOLSA (EXCLUINDO DRE), BOVESPA MAIS (MA)
### E BOVESPA MAIS NIVEL 2 (M2).
 
###########################################################
# ROTINA PARA IMPORTAR O HISTORICO DE COTACAO DOS TICKERS #
###########################################################

# INSTALAR O YAHOO QUERY

# !pip install yahooquery

# (SE NECESSARIO) INSTALAR LEITOR DE ARQUIVO XLS

# !pip install xlrd

# INICIALIZAR OS MODULOS YAHOOQUERY

import yahooquery as yq
from yahooquery import Ticker

# INICIALIZAR OS MODULOS AUXILIARES

import pandas as pd
import requests as rq
import numpy as ny

###########################################################
# IMPORTAR HISTORICO DE COTACAO DOS ATIVOS SELECIONADOS   #
# OS CODIGOS SERAO DIVIDIDOS POR SETOR ECONOMICO          #
###########################################################

# %%
### 7 ###
#################################################
### SETOR ECONOMICO: TECNOLOGIA DA INFORMACAO ###
#################################################

# INTELBRAS
INTB3 = Ticker('INTB3.SA')
hist_INTB3 = INTB3.history(period='60d', interval='5m')
ativo_INTB3 = pd.DataFrame(hist_INTB3)
INTB3_close = ativo_INTB3['close']
INTB3_close.to_excel('INTB3_close.xlsx')

# MULTILASER
MLAS3 = Ticker('MLAS3.SA')
hist_MLAS3 = MLAS3.history(period='60d', interval='5m')
ativo_MLAS3 = pd.DataFrame(hist_MLAS3)
MLAS3_close = ativo_MLAS3['close']
MLAS3_close.to_excel('MLAS3_close.xlsx')

# POSITIVO TEC
POSI3 = Ticker('POSI3.SA')
hist_POSI3 = POSI3.history(period='60d', interval='5m')
ativo_POSI3 = pd.DataFrame(hist_POSI3)
POSI3_close = ativo_POSI3['close']
POSI3_close.to_excel('POSI3_close.xlsx')

# BEMOBI TECH
BMOB3 = Ticker('BMOB3.SA')
hist_BMOB3 = BMOB3.history(period='60d', interval='5m')
ativo_BMOB3 = pd.DataFrame(hist_BMOB3)
BMOB3_close = ativo_BMOB3['close']
BMOB3_close.to_excel('BMOB3_close.xlsx')

# ENJOEI
ENJU3 = Ticker('ENJU3.SA')
hist_ENJU3 = ENJU3.history(period='60d', interval='5m')
ativo_ENJU3 = pd.DataFrame(hist_ENJU3)
ENJU3_close = ativo_ENJU3['close']
ENJU3_close.to_excel('ENJU3_close.xlsx')

# %%
# GETNINJAS
NINJ3 = Ticker('NINJ3.SA')
hist_NINJ3 = NINJ3.history(period='60d', interval='5m')
ativo_NINJ3 = pd.DataFrame(hist_NINJ3)
NINJ3_close = ativo_NINJ3['close']
NINJ3_close.to_excel('NINJ3_close.xlsx')

# INFRACOMM
IFCM3 = Ticker('IFCM3.SA')
hist_IFCM3 = IFCM3.history(period='60d', interval='5m')
ativo_IFCM3 = pd.DataFrame(hist_IFCM3)
IFCM3_close = ativo_IFCM3['close']
IFCM3_close.to_excel('IFCM3_close.xlsx')

# LOCAWEB
LWSA3 = Ticker('LWSA3.SA')
hist_LWSA3 = LWSA3.history(period='60d', interval='5m')
ativo_LWSA3 = pd.DataFrame(hist_LWSA3)
LWSA3_close = ativo_LWSA3['close']
LWSA3_close.to_excel('LWSA3_close.xlsx')

# MELIUZ
CASH3 = Ticker('CASH3.SA')
hist_CASH3 = CASH3.history(period='60d', interval='5m')
ativo_CASH3 = pd.DataFrame(hist_CASH3)
CASH3_close = ativo_CASH3['close']
CASH3_close.to_excel('CASH3_close.xlsx')

# MOBLY
MBLY3 = Ticker('MBLY3.SA')
hist_MBLY3 = MBLY3.history(period='60d', interval='5m')
ativo_MBLY3 = pd.DataFrame(hist_MBLY3)
MBLY3_close = ativo_MBLY3['close']
MBLY3_close.to_excel('MBLY3_close.xlsx')

# %%
# NEOGRID
NGRD3 = Ticker('NGRD3.SA')
hist_NGRD3 = NGRD3.history(period='60d', interval='5m')
ativo_NGRD3 = pd.DataFrame(hist_NGRD3)
NGRD3_close = ativo_NGRD3['close']
NGRD3_close.to_excel('NGRD3_close.xlsx')

# PADTEC
PDTC3 = Ticker('PDTC3.SA')
hist_PDTC3 = PDTC3.history(period='60d', interval='5m')
ativo_PDTC3 = pd.DataFrame(hist_PDTC3)
PDTC3_close = ativo_PDTC3['close']
PDTC3_close.to_excel('PDTC3_close.xlsx')

# SINQIA
SQIA3 = Ticker('SQIA3.SA')
hist_SQIA3 = SQIA3.history(period='60d', interval='5m')
ativo_SQIA3 = pd.DataFrame(hist_SQIA3)
SQIA3_close = ativo_SQIA3['close']
SQIA3_close.to_excel('SQIA3_close.xlsx')

# TC
TRAD3 = Ticker('TRAD3.SA')
hist_TRAD3 = TRAD3.history(period='60d', interval='5m')
ativo_TRAD3 = pd.DataFrame(hist_TRAD3)
TRAD3_close = ativo_TRAD3['close']
TRAD3_close.to_excel('TRAD3_close.xlsx')

# TOTVS       
TOTS3 = Ticker('TOTS3.SA')
hist_TOTS3 = TOTS3.history(period='60d', interval='5m')
ativo_TOTS3 = pd.DataFrame(hist_TOTS3)
TOTS3_close = ativo_TOTS3['close']
TOTS3_close.to_excel('TOTS3_close.xlsx')

# %%
# WDC NETWORKS
LVTC3 = Ticker('LVTC3.SA')
hist_LVTC3 = LVTC3.history(period='60d', interval='5m')
ativo_LVTC3 = pd.DataFrame(hist_LVTC3)
LVTC3_close = ativo_LVTC3['close']
LVTC3_close.to_excel('LVTC3_close.xlsx')

# WESTWING
WEST3 = Ticker('WEST3.SA')
hist_WEST3 = WEST3.history(period='60d', interval='5m')
ativo_WEST3 = pd.DataFrame(hist_WEST3)
WEST3_close = ativo_WEST3['close']
WEST3_close.to_excel('WEST3_close.xlsx')
