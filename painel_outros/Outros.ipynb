# %%
### SCRIPT PARA OBTER HISTORICO DE COTACAO DAS ACOES B3.
#
### ATE 15/09/2022 (site B3) 482 EMPRESAS COM ACOES NEGOCIAVEIS NO MERCADO A VISTA.
#
### CRITERIO DE SELECAO DOS TICKERS NEGOCIAVEIS.
### ATIVOS PERTENCENTES AOS SEGUIMENTOS NOVO MERCADO (NM),
### CIA. NIVEL 1 E 2 DE GOVERNANCA CORPORATIVA (N1 E N2),
### TRADICIONAL-BOLSA (EXCLUINDO DRE), BOVESPA MAIS (MA)
### E BOVESPA MAIS NIVEL 2 (M2).
 
###########################################################
# ROTINA PARA IMPORTAR O HISTORICO DE COTACAO DOS TICKERS #
###########################################################

# INSTALAR O YAHOO QUERY

# !pip install yahooquery

# (SE NECESSARIO) INSTALAR LEITOR DE ARQUIVO XLS

# !pip install xlrd

# INICIALIZAR OS MODULOS YAHOOQUERY

import yahooquery as yq
from yahooquery import Ticker

# INICIALIZAR OS MODULOS AUXILIARES

import pandas as pd
import requests as rq
import numpy as ny

###########################################################
# IMPORTAR HISTORICO DE COTACAO DOS ATIVOS SELECIONADOS   #
# OS CODIGOS SERAO DIVIDIDOS POR SETOR ECONOMICO          #
###########################################################

# %%
### 11 ###
###############################
### SETOR ECONOMICO: OUTROS ###
###############################

# ATOMPAR
ATOM3 = Ticker('ATOM3.SA')
hist_ATOM3 = ATOM3.history(period='60d', interval='5m')
ativo_ATOM3 = pd.DataFrame(hist_ATOM3)
ATOM3_close = ativo_ATOM3['close']
ATOM3_close.to_excel('ATOM3_close.xlsx')

# B TECH EQI
BLUT3 = Ticker('BLUT3.SA')
hist_BLUT3 = BLUT3.history(period='60d', interval='5m')
ativo_BLUT3 = pd.DataFrame(hist_BLUT3)
BLUT3_close = ativo_BLUT3['close']
BLUT3_close.to_excel('BLUT3_close.xlsx')

BLUT4 = Ticker('BLUT4.SA')
hist_BLUT4 = BLUT4.history(period='60d', interval='5m')
ativo_BLUT4 = pd.DataFrame(hist_BLUT4)
BLUT4_close = ativo_BLUT4['close']
BLUT4_close.to_excel('BLUT4_close.xlsx')

# CEMEPE      
MAPT3 = Ticker('MAPT3.SA')
hist_MAPT3 = MAPT3.history(period='60d', interval='5m')
ativo_MAPT3 = pd.DataFrame(hist_MAPT3)
MAPT3_close = ativo_MAPT3['close']
MAPT3_close.to_excel('MAPT3_close.xlsx')

MAPT4 = Ticker('MAPT4.SA')
hist_MAPT4 = MAPT4.history(period='60d', interval='5m')
ativo_MAPT4 = pd.DataFrame(hist_MAPT4)
MAPT4_close = ativo_MAPT4['close']
MAPT4_close.to_excel('MAPT4_close.xlsx')

# INVEST BEMGE
FIGE3 = Ticker('FIGE3.SA')
hist_FIGE3 = FIGE3.history(period='60d', interval='5m')
ativo_FIGE3 = pd.DataFrame(hist_FIGE3)
FIGE3_close = ativo_FIGE3['close']
FIGE3_close.to_excel('FIGE3_close.xlsx')

FIGE4 = Ticker('FIGE4.SA')
hist_FIGE4 = FIGE4.history(period='60d', interval='5m')
ativo_FIGE4 = pd.DataFrame(hist_FIGE4)
FIGE4_close = ativo_FIGE4['close']
FIGE4_close.to_excel('FIGE4_close.xlsx')

# POLPAR
PPAR3 = Ticker('PPAR3.SA')
hist_PPAR3 = PPAR3.history(period='60d', interval='5m')
ativo_PPAR3 = pd.DataFrame(hist_PPAR3)
PPAR3_close = ativo_PPAR3['close']
PPAR3_close.to_excel('PPAR3_close.xlsx')
