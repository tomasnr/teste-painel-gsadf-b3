# %%
### SCRIPT PARA OBTER HISTORICO DE COTACAO DAS ACOES B3.
#
### ATE 15/09/2022 (site B3) 482 EMPRESAS COM ACOES NEGOCIAVEIS NO MERCADO A VISTA.
#
### CRITERIO DE SELECAO DOS TICKERS NEGOCIAVEIS.
### ATIVOS PERTENCENTES AOS SEGUIMENTOS NOVO MERCADO (NM),
### CIA. NIVEL 1 E 2 DE GOVERNANCA CORPORATIVA (N1 E N2),
### TRADICIONAL-BOLSA (EXCLUINDO DRE), BOVESPA MAIS (MA)
### E BOVESPA MAIS NIVEL 2 (M2).
 
###########################################################
# ROTINA PARA IMPORTAR O HISTORICO DE COTACAO DOS TICKERS #
###########################################################

# INSTALAR O YAHOO QUERY

# !pip install yahooquery

# (SE NECESSARIO) INSTALAR LEITOR DE ARQUIVO XLS

# !pip install xlrd

# INICIALIZAR OS MODULOS YAHOOQUERY

import yahooquery as yq
from yahooquery import Ticker

# INICIALIZAR OS MODULOS AUXILIARES

import pandas as pd
import requests as rq
import numpy as ny

###########################################################
# IMPORTAR HISTORICO DE COTACAO DOS ATIVOS SELECIONADOS   #
# OS CODIGOS SERAO DIVIDIDOS POR SETOR ECONOMICO          #
###########################################################

# %%
### 8 ###
#####################################
### SETOR ECONOMICO: COMUNICACOES ###
#####################################

# BRISANET
BRIT3 = Ticker('BRIT3.SA')
hist_BRIT3 = BRIT3.history(period='60d', interval='5m')
ativo_BRIT3 = pd.DataFrame(hist_BRIT3)
BRIT3_close = ativo_BRIT3['close']
BRIT3_close.to_excel('BRIT3_close.xlsx')

# DESKTOP
DESK3 = Ticker('DESK3.SA')
hist_DESK3 = DESK3.history(period='60d', interval='5m')
ativo_DESK3 = pd.DataFrame(hist_DESK3)
DESK3_close = ativo_DESK3['close']
DESK3_close.to_excel('DESK3_close.xlsx')

# OI
OIBR3 = Ticker('OIBR3.SA')
hist_OIBR3 = OIBR3.history(period='60d', interval='5m')
ativo_OIBR3 = pd.DataFrame(hist_OIBR3)
OIBR3_close = ativo_OIBR3['close']
OIBR3_close.to_excel('OIBR3_close.xlsx')

OIBR4 = Ticker('OIBR4.SA')
hist_OIBR4 = OIBR4.history(period='60d', interval='5m')
ativo_OIBR4 = pd.DataFrame(hist_OIBR4)
OIBR4_close = ativo_OIBR4['close']
OIBR4_close.to_excel('OIBR4_close.xlsx')

# TELEBRAS    
TELB3 = Ticker('TELB3.SA')
hist_TELB3 = TELB3.history(period='60d', interval='5m')
ativo_TELB3 = pd.DataFrame(hist_TELB3)
TELB3_close = ativo_TELB3['close']
TELB3_close.to_excel('TELB3_close.xlsx')

TELB4 = Ticker('TELB4.SA')
hist_TELB4 = TELB4.history(period='60d', interval='5m')
ativo_TELB4 = pd.DataFrame(hist_TELB4)
TELB4_close = ativo_TELB4['close']
TELB4_close.to_excel('TELB4_close.xlsx')

# TELEF BRASIL
VIVT3 = Ticker('VIVT3.SA')
hist_VIVT3 = VIVT3.history(period='60d', interval='5m')
ativo_VIVT3 = pd.DataFrame(hist_VIVT3)
VIVT3_close = ativo_VIVT3['close']
VIVT3_close.to_excel('VIVT3_close.xlsx')

# TIM
TIMS3 = Ticker('TIMS3.SA')
hist_TIMS3 = TIMS3.history(period='60d', interval='5m')
ativo_TIMS3 = pd.DataFrame(hist_TIMS3)
TIMS3_close = ativo_TIMS3['close']
TIMS3_close.to_excel('TIMS3_close.xlsx')

# UNIFIQUE
FIQE3 = Ticker('FIQE3.SA')
hist_FIQE3 = FIQE3.history(period='60d', interval='5m')
ativo_FIQE3 = pd.DataFrame(hist_FIQE3)
FIQE3_close = ativo_FIQE3['close']
FIQE3_close.to_excel('FIQE3_close.xlsx')

# ELETROMIDIA
ELMD3 = Ticker('ELMD3.SA')
hist_ELMD3 = ELMD3.history(period='60d', interval='5m')
ativo_ELMD3 = pd.DataFrame(hist_ELMD3)
ELMD3_close = ativo_ELMD3['close']
ELMD3_close.to_excel('ELMD3_close.xlsx')
