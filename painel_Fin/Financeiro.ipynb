# %%
### SCRIPT PARA OBTER HISTORICO DE COTACAO DAS ACOES B3.
#
### ATE 15/09/2022 (site B3) 482 EMPRESAS COM ACOES NEGOCIAVEIS NO MERCADO A VISTA.
#
### CRITERIO DE SELECAO DOS TICKERS NEGOCIAVEIS.
### ATIVOS PERTENCENTES AOS SEGUIMENTOS NOVO MERCADO (NM),
### CIA. NIVEL 1 E 2 DE GOVERNANCA CORPORATIVA (N1 E N2),
### TRADICIONAL-BOLSA (EXCLUINDO DRE), BOVESPA MAIS (MA)
### E BOVESPA MAIS NIVEL 2 (M2).
 
###########################################################
# ROTINA PARA IMPORTAR O HISTORICO DE COTACAO DOS TICKERS #
###########################################################

# INSTALAR O YAHOO QUERY

# !pip install yahooquery

# (SE NECESSARIO) INSTALAR LEITOR DE ARQUIVO XLS

# !pip install xlrd

# INICIALIZAR OS MODULOS YAHOOQUERY

import yahooquery as yq
from yahooquery import Ticker

# INICIALIZAR OS MODULOS AUXILIARES

import pandas as pd
import requests as rq
import numpy as ny

###########################################################
# IMPORTAR HISTORICO DE COTACAO DOS ATIVOS SELECIONADOS   #
# OS CODIGOS SERAO DIVIDIDOS POR SETOR ECONOMICO          #
###########################################################

# %%
### 10 ###
###################################
### SETOR ECONOMICO: FINANCEIRO ###
###################################

# ABC BRASIL
ABCB4 = Ticker('ABCB4.SA')
hist_ABCB4 = ABCB4.history(period='60d', interval='5m')
ativo_ABCB4 = pd.DataFrame(hist_ABCB4)
ABCB4_close = ativo_ABCB4['close']
ABCB4_close.to_excel('ABCB4_close.xlsx')

# ALFA HOLDING
RPAD3 = Ticker('RPAD3.SA')
hist_RPAD3 = RPAD3.history(period='60d', interval='5m')
ativo_RPAD3 = pd.DataFrame(hist_RPAD3)
RPAD3_close = ativo_RPAD3['close']
RPAD3_close.to_excel('RPAD3_close.xlsx')

RPAD5 = Ticker('RPAD5.SA')
hist_RPAD5 = RPAD5.history(period='60d', interval='5m')
ativo_RPAD5 = pd.DataFrame(hist_RPAD5)
RPAD5_close = ativo_RPAD5['close']
RPAD5_close.to_excel('RPAD5_close.xlsx')

RPAD6 = Ticker('RPAD6.SA')
hist_RPAD6 = RPAD6.history(period='60d', interval='5m')
ativo_RPAD6 = pd.DataFrame(hist_RPAD6)
RPAD6_close = ativo_RPAD6['close']
RPAD6_close.to_excel('RPAD6_close.xlsx')

# ALFA INVEST 
BRIV3 = Ticker('BRIV3.SA')
hist_BRIV3 = BRIV3.history(period='60d', interval='5m')
ativo_BRIV3 = pd.DataFrame(hist_BRIV3)
BRIV3_close = ativo_BRIV3['close']
BRIV3_close.to_excel('BRIV3_close.xlsx')

# %%
BRIV4 = Ticker('BRIV4.SA')
hist_BRIV4 = BRIV4.history(period='60d', interval='5m')
ativo_BRIV4 = pd.DataFrame(hist_BRIV4)
BRIV4_close = ativo_BRIV4['close']
BRIV4_close.to_excel('BRIV4_close.xlsx')

# AMAZONIA    
BAZA3 = Ticker('BAZA3.SA')
hist_BAZA3 = BAZA3.history(period='60d', interval='5m')
ativo_BAZA3 = pd.DataFrame(hist_BAZA3)
BAZA3_close = ativo_BAZA3['close']
BAZA3_close.to_excel('BAZA3_close.xlsx')

# BANCO BMG
BMGB4 = Ticker('BMGB4.SA')
hist_BMGB4 = BMGB4.history(period='60d', interval='5m')
ativo_BMGB4 = pd.DataFrame(hist_BMGB4)
BMGB4_close = ativo_BMGB4['close']
BMGB4_close.to_excel('BMGB4_close.xlsx')

# BANCO PAN
BPAN4 = Ticker('BPAN4.SA')
hist_BPAN4 = BPAN4.history(period='60d', interval='5m')
ativo_BPAN4 = pd.DataFrame(hist_BPAN4)
BPAN4_close = ativo_BPAN4['close']
BPAN4_close.to_excel('BPAN4_close.xlsx')

# BANESE      
BGIP3 = Ticker('BGIP3.SA')
hist_BGIP3 = BGIP3.history(period='60d', interval='5m')
ativo_BGIP3 = pd.DataFrame(hist_BGIP3)
BGIP3_close = ativo_BGIP3['close']
BGIP3_close.to_excel('BGIP3_close.xlsx')

# %%
BGIP4 = Ticker('BGIP4.SA')
hist_BGIP4 = BGIP4.history(period='60d', interval='5m')
ativo_BGIP4 = pd.DataFrame(hist_BGIP4)
BGIP4_close = ativo_BGIP4['close']
BGIP4_close.to_excel('BGIP4_close.xlsx')

# BANESTES    
BEES3 = Ticker('BEES3.SA')
hist_BEES3 = BEES3.history(period='60d', interval='5m')
ativo_BEES3 = pd.DataFrame(hist_BEES3)
BEES3_close = ativo_BEES3['close']
BEES3_close.to_excel('BEES3_close.xlsx')

BEES4 = Ticker('BEES4.SA')
hist_BEES4 = BEES4.history(period='60d', interval='5m')
ativo_BEES4 = pd.DataFrame(hist_BEES4)
BEES4_close = ativo_BEES4['close']
BEES4_close.to_excel('BEES4_close.xlsx')

# BANRISUL
BRSR3 = Ticker('BRSR3.SA')
hist_BRSR3 = BRSR3.history(period='60d', interval='5m')
ativo_BRSR3 = pd.DataFrame(hist_BRSR3)
BRSR3_close = ativo_BRSR3['close']
BRSR3_close.to_excel('BRSR3_close.xlsx')

BRSR5 = Ticker('BRSR5.SA')
hist_BRSR5 = BRSR5.history(period='60d', interval='5m')
ativo_BRSR5 = pd.DataFrame(hist_BRSR5)
BRSR5_close = ativo_BRSR5['close']
BRSR5_close.to_excel('BRSR5_close.xlsx')

# %%
BRSR6= Ticker('BRSR6.SA')
hist_BRSR6 = BRSR6.history(period='60d', interval='5m')
ativo_BRSR6 = pd.DataFrame(hist_BRSR6)
BRSR6_close = ativo_BRSR6['close']
BRSR6_close.to_excel('BRSR6_close.xlsx')

# BR PARTNERS
BRBI11 = Ticker('BRBI11.SA')
hist_BRBI11 = BRBI11.history(period='60d', interval='5m')
ativo_BRBI11 = pd.DataFrame(hist_BRBI11)
BRBI11_close = ativo_BRBI11['close']
BRBI11_close.to_excel('BRBI11_close.xlsx')

# BRADESCO    
BBDC3 = Ticker('BBDC3.SA')
hist_BBDC3 = BBDC3.history(period='60d', interval='5m')
ativo_BBDC3 = pd.DataFrame(hist_BBDC3)
BBDC3_close = ativo_BBDC3['close']
BBDC3_close.to_excel('BBDC3_close.xlsx')

BBDC4 = Ticker('BBDC4.SA')
hist_BBDC4 = BBDC4.history(period='60d', interval='5m')
ativo_BBDC4 = pd.DataFrame(hist_BBDC4)
BBDC4_close = ativo_BBDC4['close']
BBDC4_close.to_excel('BBDC4_close.xlsx')

# BRASIL      
BBAS3 = Ticker('BBAS3.SA')
hist_BBAS3 = BBAS3.history(period='60d', interval='5m')
ativo_BBAS3 = pd.DataFrame(hist_BBAS3)
BBAS3_close = ativo_BBAS3['close']
BBAS3_close.to_excel('BBAS3_close.xlsx')

# %%
# BRB BANCO   
BSLI3 = Ticker('BSLI3.SA')
hist_BSLI3 = BSLI3.history(period='60d', interval='5m')
ativo_BSLI3 = pd.DataFrame(hist_BSLI3)
BSLI3_close = ativo_BSLI3['close']
BSLI3_close.to_excel('BSLI3_close.xlsx')

BSLI4 = Ticker('BSLI4.SA')
hist_BSLI4 = BSLI4.history(period='60d', interval='5m')
ativo_BSLI4 = pd.DataFrame(hist_BSLI4)
BSLI4_close = ativo_BSLI4['close']
BSLI4_close.to_excel('BSLI4_close.xlsx')

# BTGP BANCO
BPAC3 = Ticker('BPAC3.SA')
hist_BPAC3 = BPAC3.history(period='60d', interval='5m')
ativo_BPAC3 = pd.DataFrame(hist_BPAC3)
BPAC3_close = ativo_BPAC3['close']
BPAC3_close.to_excel('BPAC3_close.xlsx')

BPAC5 = Ticker('BPAC5.SA')
hist_BPAC5 = BPAC5.history(period='60d', interval='5m')
ativo_BPAC5 = pd.DataFrame(hist_BPAC5)
BPAC5_close = ativo_BPAC5['close']
BPAC5_close.to_excel('BPAC5_close.xlsx')

BPAC11 = Ticker('BPAC11.SA')
hist_BPAC11 = BPAC11.history(period='60d', interval='5m')
ativo_BPAC11 = pd.DataFrame(hist_BPAC11)
BPAC11_close = ativo_BPAC11['close']
BPAC11_close.to_excel('BPAC11_close.xlsx')

# %%
# ITAUSA      
ITSA3 = Ticker('ITSA3.SA')
hist_ITSA3 = ITSA3.history(period='60d', interval='5m')
ativo_ITSA3 = pd.DataFrame(hist_ITSA3)
ITSA3_close = ativo_ITSA3['close']
ITSA3_close.to_excel('ITSA3_close.xlsx')

ITSA4 = Ticker('ITSA4.SA')
hist_ITSA4 = ITSA4.history(period='60d', interval='5m')
ativo_ITSA4 = pd.DataFrame(hist_ITSA4)
ITSA4_close = ativo_ITSA4['close']
ITSA4_close.to_excel('ITSA4_close.xlsx')

# ITAUUNIBANCO
ITUB3 = Ticker('ITUB3.SA')
hist_ITUB3 = ITUB3.history(period='60d', interval='5m')
ativo_ITUB3 = pd.DataFrame(hist_ITUB3)
ITUB3_close = ativo_ITUB3['close']
ITUB3_close.to_excel('ITUB3_close.xlsx')

ITUB4 = Ticker('ITUB4.SA')
hist_ITUB4 = ITUB4.history(period='60d', interval='5m')
ativo_ITUB4 = pd.DataFrame(hist_ITUB4)
ITUB4_close = ativo_ITUB4['close']
ITUB4_close.to_excel('ITUB4_close.xlsx')

# MERC BRASIL 
BMEB3 = Ticker('BMEB3.SA')
hist_BMEB3 = BMEB3.history(period='60d', interval='5m')
ativo_BMEB3 = pd.DataFrame(hist_BMEB3)
BMEB3_close = ativo_BMEB3['close']
BMEB3_close.to_excel('BMEB3_close.xlsx')

# %%
BMEB4 = Ticker('BMEB4.SA')
hist_BMEB4 = BMEB4.history(period='60d', interval='5m')
ativo_BMEB4 = pd.DataFrame(hist_BMEB4)
BMEB4_close = ativo_BMEB4['close']
BMEB4_close.to_excel('BMEB4_close.xlsx')

# MERC INVEST 
BMIN3 = Ticker('BMIN3.SA')
hist_BMIN3 = BMIN3.history(period='60d', interval='5m')
ativo_BMIN3 = pd.DataFrame(hist_BMIN3)
BMIN3_close = ativo_BMIN3['close']
BMIN3_close.to_excel('BMIN3_close.xlsx')

BMIN4 = Ticker('BMIN4.SA')
hist_BMIN4 = BMIN4.history(period='60d', interval='5m')
ativo_BMIN4 = pd.DataFrame(hist_BMIN4)
BMIN4_close = ativo_BMIN4['close']
BMIN4_close.to_excel('BMIN4_close.xlsx')

# MODALMAIS
MODL3 = Ticker('MODL3.SA')
hist_MODL3 = MODL3.history(period='60d', interval='5m')
ativo_MODL3 = pd.DataFrame(hist_MODL3)
MODL3_close = ativo_MODL3['close']
MODL3_close.to_excel('MODL3_close.xlsx')

MODL4 = Ticker('MODL4.SA')
hist_MODL4 = MODL4.history(period='60d', interval='5m')
ativo_MODL4 = pd.DataFrame(hist_MODL4)
MODL4_close = ativo_MODL4['close']
MODL4_close.to_excel('MODL4_close.xlsx')

# %%
# NORD BRASIL 
BNBR3 = Ticker('BNBR3.SA')
hist_BNBR3 = BNBR3.history(period='60d', interval='5m')
ativo_BNBR3 = pd.DataFrame(hist_BNBR3)
BNBR3_close = ativo_BNBR3['close']
BNBR3_close.to_excel('BNBR3_close.xlsx')

# PINE        
PINE4 = Ticker('PINE4.SA')
hist_PINE4 = PINE4.history(period='60d', interval='5m')
ativo_PINE4 = pd.DataFrame(hist_PINE4)
PINE4_close = ativo_PINE4['close']
PINE4_close.to_excel('PINE4_close.xlsx')

# SANTANDER BR
SANB3 = Ticker('SANB3.SA')
hist_SANB3 = SANB3.history(period='60d', interval='5m')
ativo_SANB3 = pd.DataFrame(hist_SANB3)
SANB3_close = ativo_SANB3['close']
SANB3_close.to_excel('SANB3_close.xlsx')

SANB4 = Ticker('SANB4.SA')
hist_SANB4 = SANB4.history(period='60d', interval='5m')
ativo_SANB4 = pd.DataFrame(hist_SANB4)
SANB4_close = ativo_SANB4['close']
SANB4_close.to_excel('SANB4_close.xlsx')

SANB11 = Ticker('SANB11.SA')
hist_SANB11 = SANB11.history(period='60d', interval='5m')
ativo_SANB11 = pd.DataFrame(hist_SANB11)
SANB11_close = ativo_SANB11['close']
SANB11_close.to_excel('SANB11_close.xlsx')

# %%
# ALFA FINANC 
CRIV3 = Ticker('CRIV3.SA')
hist_CRIV3 = CRIV3.history(period='60d', interval='5m')
ativo_CRIV3 = pd.DataFrame(hist_CRIV3)
CRIV3_close = ativo_CRIV3['close']
CRIV3_close.to_excel('CRIV3_close.xlsx')

CRIV4 = Ticker('CRIV4.SA')
hist_CRIV4 = CRIV4.history(period='60d', interval='5m')
ativo_CRIV4 = pd.DataFrame(hist_CRIV4)
CRIV4_close = ativo_CRIV4['close']
CRIV4_close.to_excel('CRIV4_close.xlsx')

# DMFINANCEIRA
DMFN3 = Ticker('DMFN3.SA')
hist_DMFN3 = DMFN3.history(period='60d', interval='5m')
ativo_DMFN3 = pd.DataFrame(hist_DMFN3)
DMFN3_close = ativo_DMFN3['close']
DMFN3_close.to_excel('DMFN3_close.xlsx')

# MERC FINANC
MERC3 = Ticker('MERC3.SA')
hist_MERC3 = MERC3.history(period='60d', interval='5m')
ativo_MERC3 = pd.DataFrame(hist_MERC3)
MERC3_close = ativo_MERC3['close']
MERC3_close.to_excel('MERC3_close.xlsx')

MERC4 = Ticker('MERC4.SA')
hist_MERC4 = MERC4.history(period='60d', interval='5m')
ativo_MERC4 = pd.DataFrame(hist_MERC4)
MERC4_close = ativo_MERC4['close']
MERC4_close.to_excel('MERC4_close.xlsx')

# %%
# G2D INVEST
G2DI33 = Ticker('G2DI33.SA')
hist_G2DI33 = G2DI33.history(period='60d', interval='5m')
ativo_G2DI33 = pd.DataFrame(hist_G2DI33)
G2DI33_close = ativo_G2DI33['close']
G2DI33_close.to_excel('G2DI33_close.xlsx')

# B3
B3SA3 = Ticker('B3SA3.SA')
hist_B3SA3 = B3SA3.history(period='60d', interval='5m')
ativo_B3SA3 = pd.DataFrame(hist_B3SA3)
B3SA3_close = ativo_B3SA3['close']
B3SA3_close.to_excel('B3SA3_close.xlsx')

# BOA VISTA
BOAS3 = Ticker('BOAS3.SA')
hist_BOAS3 = BOAS3.history(period='60d', interval='5m')
ativo_BOAS3 = pd.DataFrame(hist_BOAS3)
BOAS3_close = ativo_BOAS3['close']
BOAS3_close.to_excel('BOAS3_close.xlsx')

# CIELO       
CIEL3 = Ticker('CIEL3.SA')
hist_CIEL3 = CIEL3.history(period='60d', interval='5m')
ativo_CIEL3 = pd.DataFrame(hist_CIEL3)
CIEL3_close = ativo_CIEL3['close']
CIEL3_close.to_excel('CIEL3_close.xlsx')

# CLEARSALE
CLSA3 = Ticker('CLSA3.SA')
hist_CLSA3 = CLSA3.history(period='60d', interval='5m')
ativo_CLSA3 = pd.DataFrame(hist_CLSA3)
CLSA3_close = ativo_CLSA3['close']
CLSA3_close.to_excel('CLSA3_close.xlsx')

# %%
# CSU DIGITAL
CSUD3 = Ticker('CSUD3.SA')
hist_CSUD3 = CSUD3.history(period='60d', interval='5m')
ativo_CSUD3 = pd.DataFrame(hist_CSUD3)
CSUD3_close = ativo_CSUD3['close']
CSUD3_close.to_excel('CSUD3_close.xlsx')

# GETNET BR
GETT3 = Ticker('GETT3.SA')
hist_GETT3 = GETT3.history(period='60d', interval='5m')
ativo_GETT3 = pd.DataFrame(hist_GETT3)
GETT3_close = ativo_GETT3['close']
GETT3_close.to_excel('GETT3_close.xlsx')

GETT4 = Ticker('GETT4.SA')
hist_GETT4 = GETT4.history(period='60d', interval='5m')
ativo_GETT4 = pd.DataFrame(hist_GETT4)
GETT4_close = ativo_GETT4['close']
GETT4_close.to_excel('GETT4_close.xlsx')

GETT11 = Ticker('GETT11.SA')
hist_GETT11 = GETT11.history(period='60d', interval='5m')
ativo_GETT11 = pd.DataFrame(hist_GETT11)
GETT11_close = ativo_GETT11['close']
GETT11_close.to_excel('GETT11_close.xlsx')

# ALFA CONSORC
BRGE3 = Ticker('BRGE3.SA')
hist_BRGE3 = BRGE3.history(period='60d', interval='5m')
ativo_BRGE3 = pd.DataFrame(hist_BRGE3)
BRGE3_close = ativo_BRGE3['close']
BRGE3_close.to_excel('BRGE3_close.xlsx')

# %%
BRGE5 = Ticker('BRGE5.SA')
hist_BRGE5 = BRGE5.history(period='60d', interval='5m')
ativo_BRGE5 = pd.DataFrame(hist_BRGE5)
BRGE5_close = ativo_BRGE5['close']
BRGE5_close.to_excel('BRGE5_close.xlsx')

BRGE6 = Ticker('BRGE6.SA')
hist_BRGE6 = BRGE6.history(period='60d', interval='5m')
ativo_BRGE6 = pd.DataFrame(hist_BRGE6)
BRGE6_close = ativo_BRGE6['close']
BRGE6_close.to_excel('BRGE6_close.xlsx')

BRGE8 = Ticker('BRGE8.SA')
hist_BRGE8 = BRGE8.history(period='60d', interval='5m')
ativo_BRGE8 = pd.DataFrame(hist_BRGE8)
BRGE8_close = ativo_BRGE8['close']
BRGE8_close.to_excel('BRGE8_close.xlsx')

BRGE11 = Ticker('BRGE11.SA')
hist_BRGE11 = BRGE11.history(period='60d', interval='5m')
ativo_BRGE11 = pd.DataFrame(hist_BRGE11)
BRGE11_close = ativo_BRGE11['close']
BRGE11_close.to_excel('BRGE11_close.xlsx')

BRGE12 = Ticker('BRGE12.SA')
hist_BRGE12 = BRGE12.history(period='60d', interval='5m')
ativo_BRGE12 = pd.DataFrame(hist_BRGE12)
BRGE12_close = ativo_BRGE12['close']
BRGE12_close.to_excel('BRGE12_close.xlsx')

# %%
# BBSEGURIDADE
BBSE3 = Ticker('BBSE3.SA')
hist_BBSE3 = BBSE3.history(period='60d', interval='5m')
ativo_BBSE3 = pd.DataFrame(hist_BBSE3)
BBSE3_close = ativo_BBSE3['close']
BBSE3_close.to_excel('BBSE3_close.xlsx')

# CAIXA SEGURI
CXSE3 = Ticker('CXSE3.SA')
hist_CXSE3 = CXSE3.history(period='60d', interval='5m')
ativo_CXSE3 = pd.DataFrame(hist_CXSE3)
CXSE3_close = ativo_CXSE3['close']
CXSE3_close.to_excel('CXSE3_close.xlsx')

# PORTO SEGURO
PSSA3 = Ticker('PSSA3.SA')
hist_PSSA3 = PSSA3.history(period='60d', interval='5m')
ativo_PSSA3 = pd.DataFrame(hist_PSSA3)
PSSA3_close = ativo_PSSA3['close']
PSSA3_close.to_excel('PSSA3_close.xlsx')

# SEG AL BAHIA
CSAB3 = Ticker('CSAB3.SA')
hist_CSAB3 = CSAB3.history(period='60d', interval='5m')
ativo_CSAB3 = pd.DataFrame(hist_CSAB3)
CSAB3_close = ativo_CSAB3['close']
CSAB3_close.to_excel('CSAB3_close.xlsx')

CSAB4 = Ticker('CSAB4.SA')
hist_CSAB4 = CSAB4.history(period='60d', interval='5m')
ativo_CSAB4 = pd.DataFrame(hist_CSAB4)
CSAB4_close = ativo_CSAB4['close']
CSAB4_close.to_excel('CSAB4_close.xlsx')

# %%
# SUL AMERICA 
SULA3 = Ticker('SULA3.SA')
hist_SULA3 = SULA3.history(period='60d', interval='5m')
ativo_SULA3 = pd.DataFrame(hist_SULA3)
SULA3_close = ativo_SULA3['close']
SULA3_close.to_excel('SULA3_close.xlsx')

SULA4 = Ticker('SULA4.SA')
hist_SULA4 = SULA4.history(period='60d', interval='5m')
ativo_SULA4 = pd.DataFrame(hist_SULA4)
SULA4_close = ativo_SULA4['close']
SULA4_close.to_excel('SULA4_close.xlsx')

SULA11 = Ticker('SULA11.SA')
hist_SULA11 = SULA11.history(period='60d', interval='5m')
ativo_SULA11 = pd.DataFrame(hist_SULA11)
SULA11_close = ativo_SULA11['close']
SULA11_close.to_excel('SULA11_close.xlsx')

# IRBBRASIL RE
IRBR3 = Ticker('IRBR3.SA')
hist_IRBR3 = IRBR3.history(period='60d', interval='5m')
ativo_IRBR3 = pd.DataFrame(hist_IRBR3)
IRBR3_close = ativo_IRBR3['close']
IRBR3_close.to_excel('IRBR3_close.xlsx')

# WIZ S.A.
WIZS3 = Ticker('WIZS3.SA')
hist_WIZS3 = WIZS3.history(period='60d', interval='5m')
ativo_WIZS3 = pd.DataFrame(hist_WIZS3)
WIZS3_close = ativo_WIZS3['close']
WIZS3_close.to_excel('WIZS3_close.xlsx')

# %%
# ALIANSCSONAE
ALSO3 = Ticker('ALSO3.SA')
hist_ALSO3 = ALSO3.history(period='60d', interval='5m')
ativo_ALSO3 = pd.DataFrame(hist_ALSO3)
ALSO3_close = ativo_ALSO3['close']
ALSO3_close.to_excel('ALSO3_close.xlsx')

# BR MALLS PAR
BRML3 = Ticker('BRML3.SA')
hist_BRML3 = BRML3.history(period='60d', interval='5m')
ativo_BRML3 = pd.DataFrame(hist_BRML3)
BRML3_close = ativo_BRML3['close']
BRML3_close.to_excel('BRML3_close.xlsx')

# BR PROPERT  
BRPR3 = Ticker('BRPR3.SA')
hist_BRPR3 = BRPR3.history(period='60d', interval='5m')
ativo_BRPR3 = pd.DataFrame(hist_BRPR3)
BRPR3_close = ativo_BRPR3['close']
BRPR3_close.to_excel('BRPR3_close.xlsx')

# COR RIBEIRO 
CORR3 = Ticker('CORR3.SA')
hist_CORR3 = CORR3.history(period='60d', interval='5m')
ativo_CORR3 = pd.DataFrame(hist_CORR3)
CORR3_close = ativo_CORR3['close']
CORR3_close.to_excel('CORR3_close.xlsx')

# GENERALSHOPP
GSHP3 = Ticker('GSHP3.SA')
hist_GSHP3 = GSHP3.history(period='60d', interval='5m')
ativo_GSHP3 = pd.DataFrame(hist_GSHP3)
GSHP3_close = ativo_GSHP3['close']
GSHP3_close.to_excel('GSHP3_close.xlsx')

# %%
# HABITASUL   
HBTS5 = Ticker('HBTS5.SA')
hist_HBTS5 = HBTS5.history(period='60d', interval='5m')
ativo_HBTS5 = pd.DataFrame(hist_HBTS5)
HBTS5_close = ativo_HBTS5['close']
HBTS5_close.to_excel('HBTS5_close.xlsx')

# HBR REALTY
HBRE3 = Ticker('HBRE3.SA')
hist_HBRE3 = HBRE3.history(period='60d', interval='5m')
ativo_HBRE3 = pd.DataFrame(hist_HBRE3)
HBRE3_close = ativo_HBRE3['close']
HBRE3_close.to_excel('HBRE3_close.xlsx')

# IGB S/A     
IGBR3 = Ticker('IGBR3.SA')
hist_IGBR3 = IGBR3.history(period='60d', interval='5m')
ativo_IGBR3 = pd.DataFrame(hist_IGBR3)
IGBR3_close = ativo_IGBR3['close']
IGBR3_close.to_excel('IGBR3_close.xlsx')

# IGUATEMI S.A
IGTI3 = Ticker('IGTI3.SA')
hist_IGTI3 = IGTI3.history(period='60d', interval='5m')
ativo_IGTI3 = pd.DataFrame(hist_IGTI3)
IGTI3_close = ativo_IGTI3['close']
IGTI3_close.to_excel('IGTI3_close.xlsx')

IGTI4 = Ticker('IGTI4.SA')
hist_IGTI4 = IGTI4.history(period='60d', interval='5m')
ativo_IGTI4 = pd.DataFrame(hist_IGTI4)
IGTI4_close = ativo_IGTI4['close']
IGTI4_close.to_excel('IGTI4_close.xlsx')

# %%
IGTI11 = Ticker('IGTI11.SA')
hist_IGTI11 = IGTI11.history(period='60d', interval='5m')
ativo_IGTI11 = pd.DataFrame(hist_IGTI11)
IGTI11_close = ativo_IGTI11['close']
IGTI11_close.to_excel('IGTI11_close.xlsx')

# LOG COM PROP
LOGG3 = Ticker('LOGG3.SA')
hist_LOGG3 = LOGG3.history(period='60d', interval='5m')
ativo_LOGG3 = pd.DataFrame(hist_LOGG3)
LOGG3_close = ativo_LOGG3['close']
LOGG3_close.to_excel('LOGG3_close.xlsx')

# MULTIPLAN   
MULT3 = Ticker('MULT3.SA')
hist_MULT3 = MULT3.history(period='60d', interval='5m')
ativo_MULT3 = pd.DataFrame(hist_MULT3)
MULT3_close = ativo_MULT3['close']
MULT3_close.to_excel('MULT3_close.xlsx')

# SAO CARLOS  
SCAR3 = Ticker('SCAR3.SA')
hist_SCAR3 = SCAR3.history(period='60d', interval='5m')
ativo_SCAR3 = pd.DataFrame(hist_SCAR3)
SCAR3_close = ativo_SCAR3['close']
SCAR3_close.to_excel('SCAR3_close.xlsx')

# SYN PROP TEC
SYNE3 = Ticker('SYNE3.SA')
hist_SYNE3 = SYNE3.history(period='60d', interval='5m')
ativo_SYNE3 = pd.DataFrame(hist_SYNE3)
SYNE3_close = ativo_SYNE3['close']
SYNE3_close.to_excel('SYNE3_close.xlsx')

# %%
# LOPES BRASIL
LPSB3 = Ticker('LPSB3.SA')
hist_LPSB3 = LPSB3.history(period='60d', interval='5m')
ativo_LPSB3 = pd.DataFrame(hist_LPSB3)
LPSB3_close = ativo_LPSB3['close']
LPSB3_close.to_excel('LPSB3_close.xlsx')

# NEXPE
NEXP3 = Ticker('NEXP3.SA')
hist_NEXP3 = NEXP3.history(period='60d', interval='5m')
ativo_NEXP3 = pd.DataFrame(hist_NEXP3)
NEXP3_close = ativo_NEXP3['close']
NEXP3_close.to_excel('NEXP3_close.xlsx')

# MONT ARANHA 
MOAR3 = Ticker('MOAR3.SA')
hist_MOAR3 = MOAR3.history(period='60d', interval='5m')
ativo_MOAR3 = pd.DataFrame(hist_MOAR3)
MOAR3_close = ativo_MOAR3['close']
MOAR3_close.to_excel('MOAR3_close.xlsx')

# PAR AL BAHIA
PEAB3 = Ticker('PEAB3.SA')
hist_PEAB3 = PEAB3.history(period='60d', interval='5m')
ativo_PEAB3 = pd.DataFrame(hist_PEAB3)
PEAB3_close = ativo_PEAB3['close']
PEAB3_close.to_excel('PEAB3_close.xlsx')

PEAB4 = Ticker('PEAB4.SA')
hist_PEAB4 = PEAB4.history(period='60d', interval='5m')
ativo_PEAB4 = pd.DataFrame(hist_PEAB4)
PEAB4_close = ativo_PEAB4['close']
PEAB4_close.to_excel('PEAB4_close.xlsx')

# SIMPAR
SIMH3 = Ticker('SIMH3.SA')
hist_SIMH3 = SIMH3.history(period='60d', interval='5m')
ativo_SIMH3 = pd.DataFrame(hist_SIMH3)
SIMH3_close = ativo_SIMH3['close']
SIMH3_close.to_excel('SIMH3_close.xlsx')
