# %%
### SCRIPT PARA OBTER HISTORICO DE COTACAO DAS ACOES B3.
#
### ATE 15/09/2022 (site B3) 482 EMPRESAS COM ACOES NEGOCIAVEIS NO MERCADO A VISTA.
#
### CRITERIO DE SELECAO DOS TICKERS NEGOCIAVEIS.
### ATIVOS PERTENCENTES AOS SEGUIMENTOS NOVO MERCADO (NM),
### CIA. NIVEL 1 E 2 DE GOVERNANCA CORPORATIVA (N1 E N2),
### TRADICIONAL-BOLSA (EXCLUINDO DRE), BOVESPA MAIS (MA)
### E BOVESPA MAIS NIVEL 2 (M2).
 
###########################################################
# ROTINA PARA IMPORTAR O HISTORICO DE COTACAO DOS TICKERS #
###########################################################

# INSTALAR O YAHOO QUERY

# !pip install yahooquery

# (SE NECESSARIO) INSTALAR LEITOR DE ARQUIVO XLS

# !pip install xlrd

# INICIALIZAR OS MODULOS YAHOOQUERY

import yahooquery as yq
from yahooquery import Ticker

# INICIALIZAR OS MODULOS AUXILIARES

import pandas as pd
import requests as rq
import numpy as ny

###########################################################
# IMPORTAR HISTORICO DE COTACAO DOS ATIVOS SELECIONADOS   #
# OS CODIGOS SERAO DIVIDIDOS POR SETOR ECONOMICO          #
###########################################################

# %%
### 6 ###
##############################
### SETOR ECONOMICO: SAUDE ###
##############################

# BIOMM       
BIOM3 = Ticker('BIOM3.SA')
hist_BIOM3 = BIOM3.history(period='60d', interval='5m')
ativo_BIOM3 = pd.DataFrame(hist_BIOM3)
BIOM3_close = ativo_BIOM3['close']
BIOM3_close.to_excel('BIOM3_close.xlsx')

# OUROFINO S/A
OFSA3 = Ticker('OFSA3.SA')
hist_OFSA3 = OFSA3.history(period='60d', interval='5m')
ativo_OFSA3 = pd.DataFrame(hist_OFSA3)
OFSA3_close = ativo_OFSA3['close']
OFSA3_close.to_excel('OFSA3_close.xlsx')

# ALLIAR
AALR3 = Ticker('AALR3.SA')
hist_AALR3 = AALR3.history(period='60d', interval='5m')
ativo_AALR3 = pd.DataFrame(hist_AALR3)
AALR3_close = ativo_AALR3['close']
AALR3_close.to_excel('AALR3_close.xlsx')

# DASA        
DASA3 = Ticker('DASA3.SA')
hist_DASA3 = DASA3.history(period='60d', interval='5m')
ativo_DASA3 = pd.DataFrame(hist_DASA3)
DASA3_close = ativo_DASA3['close']
DASA3_close.to_excel('DASA3_close.xlsx')

# FLEURY      
FLRY3 = Ticker('FLRY3.SA')
hist_FLRY3 = FLRY3.history(period='60d', interval='5m')
ativo_FLRY3 = pd.DataFrame(hist_FLRY3)
FLRY3_close = ativo_FLRY3['close']
FLRY3_close.to_excel('FLRY3_close.xlsx')

# %%
# HAPVIDA
HAPV3 = Ticker('HAPV3.SA')
hist_HAPV3 = HAPV3.history(period='60d', interval='5m')
ativo_HAPV3 = pd.DataFrame(hist_HAPV3)
HAPV3_close = ativo_HAPV3['close']
HAPV3_close.to_excel('HAPV3_close.xlsx')

#HAPV99 = Ticker('HAPV99.SA')
#hist_HAPV99 = HAPV99.history(period='60d', interval='5m')
#ativo_HAPV99 = pd.DataFrame(hist_HAPV99)
#HAPV99_close = ativo_HAPV99['close']
#HAPV99_close.to_excel('HAPV99_close.xlsx')

# IHPARDINI
PARD3 = Ticker('PARD3.SA')
hist_PARD3 = PARD3.history(period='60d', interval='5m')
ativo_PARD3 = pd.DataFrame(hist_PARD3)
PARD3_close = ativo_PARD3['close']
PARD3_close.to_excel('PARD3_close.xlsx')

# KORA SAUDE
KRSA3 = Ticker('KRSA3.SA')
hist_KRSA3 = KRSA3.history(period='60d', interval='5m')
ativo_KRSA3 = pd.DataFrame(hist_KRSA3)
KRSA3_close = ativo_KRSA3['close']
KRSA3_close.to_excel('KRSA3_close.xlsx')

# MATER DEI
MATD3 = Ticker('MATD3.SA')
hist_MATD3 = MATD3.history(period='60d', interval='5m')
ativo_MATD3 = pd.DataFrame(hist_MATD3)
MATD3_close = ativo_MATD3['close']
MATD3_close.to_excel('MATD3_close.xlsx')

# %%
# ODONTOPREV  
ODPV3 = Ticker('ODPV3.SA')
hist_ODPV3 = ODPV3.history(period='60d', interval='5m')
ativo_ODPV3 = pd.DataFrame(hist_ODPV3)
ODPV3_close = ativo_ODPV3['close']
ODPV3_close.to_excel('ODPV3_close.xlsx')

# ONCOCLINICAS
ONCO3 = Ticker('ONCO3.SA')
hist_ONCO3 = ONCO3.history(period='60d', interval='5m')
ativo_ONCO3 = pd.DataFrame(hist_ONCO3)
ONCO3_close = ativo_ONCO3['close']
ONCO3_close.to_excel('ONCO3_close.xlsx')

# QUALICORP   
QUAL3 = Ticker('QUAL3.SA')
hist_QUAL3 = QUAL3.history(period='60d', interval='5m')
ativo_QUAL3 = pd.DataFrame(hist_QUAL3)
QUAL3_close = ativo_QUAL3['close']
QUAL3_close.to_excel('QUAL3_close.xlsx')

# REDE D OR
RDOR3 = Ticker('RDOR3.SA')
hist_RDOR3 = RDOR3.history(period='60d', interval='5m')
ativo_RDOR3 = pd.DataFrame(hist_RDOR3)
RDOR3_close = ativo_RDOR3['close']
RDOR3_close.to_excel('RDOR3_close.xlsx')

# BAUMER      
BALM3 = Ticker('BALM3.SA')
hist_BALM3 = BALM3.history(period='60d', interval='5m')
ativo_BALM3 = pd.DataFrame(hist_BALM3)
BALM3_close = ativo_BALM3['close']
BALM3_close.to_excel('BALM3_close.xlsx')

# %%
BALM4 = Ticker('BALM4.SA')
hist_BALM4 = BALM4.history(period='60d', interval='5m')
ativo_BALM4 = pd.DataFrame(hist_BALM4)
BALM4_close = ativo_BALM4['close']
BALM4_close.to_excel('BALM4_close.xlsx')

# BLAU
BLAU3 = Ticker('BLAU3.SA')
hist_BLAU3 = BLAU3.history(period='60d', interval='5m')
ativo_BLAU3 = pd.DataFrame(hist_BLAU3)
BLAU3_close = ativo_BLAU3['close']
BLAU3_close.to_excel('BLAU3_close.xlsx')

# D1000VFARMA
DMVF3 = Ticker('DMVF3.SA')
hist_DMVF3 = DMVF3.history(period='60d', interval='5m')
ativo_DMVF3 = pd.DataFrame(hist_DMVF3)
DMVF3_close = ativo_DMVF3['close']
DMVF3_close.to_excel('DMVF3_close.xlsx')

# DIMED       
PNVL3 = Ticker('PNVL3.SA')
hist_PNVL3 = PNVL3.history(period='60d', interval='5m')
ativo_PNVL3 = pd.DataFrame(hist_PNVL3)
PNVL3_close = ativo_PNVL3['close']
PNVL3_close.to_excel('PNVL3_close.xlsx')

# HYPERA
HYPE3 = Ticker('HYPE3.SA')
hist_HYPE3 = HYPE3.history(period='60d', interval='5m')
ativo_HYPE3 = pd.DataFrame(hist_HYPE3)
HYPE3_close = ativo_HYPE3['close']
HYPE3_close.to_excel('HYPE3_close.xlsx')

# %%
# PAGUE MENOS
PGMN3 = Ticker('PGMN3.SA')
hist_PGMN3 = PGMN3.history(period='60d', interval='5m')
ativo_PGMN3 = pd.DataFrame(hist_PGMN3)
PGMN3_close = ativo_PGMN3['close']
PGMN3_close.to_excel('PGMN3_close.xlsx')

# PROFARMA    
PFRM3 = Ticker('PFRM3.SA')
hist_PFRM3 = PFRM3.history(period='60d', interval='5m')
ativo_PFRM3 = pd.DataFrame(hist_PFRM3)
PFRM3_close = ativo_PFRM3['close']
PFRM3_close.to_excel('PFRM3_close.xlsx')

# RAIADROGASIL    
RADL3 = Ticker('RADL3.SA')
hist_RADL3 = RADL3.history(period='60d', interval='5m')
ativo_RADL3 = pd.DataFrame(hist_RADL3)
RADL3_close = ativo_RADL3['close']
RADL3_close.to_excel('RADL3_close.xlsx')

# VIVEO
VVEO3 = Ticker('VVEO3.SA')
hist_VVEO3 = VVEO3.history(period='60d', interval='5m')
ativo_VVEO3 = pd.DataFrame(hist_VVEO3)
VVEO3_close = ativo_VVEO3['close']
VVEO3_close.to_excel('VVEO3_close.xlsx')
