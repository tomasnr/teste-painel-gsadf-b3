# %%
### SCRIPT PARA OBTER HISTORICO DE COTACAO DAS ACOES B3.
#
### ATE 15/09/2022 (site B3) 482 EMPRESAS COM ACOES NEGOCIAVEIS NO MERCADO A VISTA.
#
### CRITERIO DE SELECAO DOS TICKERS NEGOCIAVEIS.
### ATIVOS PERTENCENTES AOS SEGUIMENTOS NOVO MERCADO (NM),
### CIA. NIVEL 1 E 2 DE GOVERNANCA CORPORATIVA (N1 E N2),
### TRADICIONAL-BOLSA (EXCLUINDO DRE), BOVESPA MAIS (MA)
### E BOVESPA MAIS NIVEL 2 (M2).
 
###########################################################
# ROTINA PARA IMPORTAR O HISTORICO DE COTACAO DOS TICKERS #
###########################################################

# INSTALAR O YAHOO QUERY

# !pip install yahooquery

# (SE NECESSARIO) INSTALAR LEITOR DE ARQUIVO XLS

# !pip install xlrd

# INICIALIZAR OS MODULOS YAHOOQUERY

import yahooquery as yq
from yahooquery import Ticker

# INICIALIZAR OS MODULOS AUXILIARES

import pandas as pd
import requests as rq
import numpy as ny

###########################################################
# IMPORTAR HISTORICO DE COTACAO DOS ATIVOS SELECIONADOS   #
# OS CODIGOS SERAO DIVIDIDOS POR SETOR ECONOMICO          #
###########################################################

# %%
### 2 ###
##########################################
### SETOR ECONOMICO: MATERIAIS BASICOS ###
##########################################

# BRADESPAR   
BRAP3 = Ticker('BRAP3.SA')
hist_BRAP3 = BRAP3.history(period='60d', interval='5m')
ativo_BRAP3 = pd.DataFrame(hist_BRAP3)
BRAP3_close = ativo_BRAP3['close']
BRAP3_close.to_excel('BRAP3_close.xlsx')

BRAP4 = Ticker('BRAP4.SA')
hist_BRAP4 = BRAP4.history(period='60d', interval='5m')
ativo_BRAP4 = pd.DataFrame(hist_BRAP4)
BRAP4_close = ativo_BRAP4['close']
BRAP4_close.to_excel('BRAP4_close.xlsx')

# CBA
CBAV3 = Ticker('CBAV3.SA')
hist_CBAV3 = CBAV3.history(period='60d', interval='5m')
ativo_CBAV3 = pd.DataFrame(hist_CBAV3)
CBAV3_close = ativo_CBAV3['close']
CBAV3_close.to_excel('CBAV3_close.xlsx')

# CSNMINERACAO
CMIN3 = Ticker('CMIN3.SA')
hist_CMIN3 = CMIN3.history(period='60d', interval='5m')
ativo_CMIN3 = pd.DataFrame(hist_CMIN3)
CMIN3_close = ativo_CMIN3['close']
CMIN3_close.to_excel('CMIN3_close.xlsx')

# VALE
VALE3 = Ticker('VALE3.SA')
hist_VALE3 = VALE3.history(period='60d', interval='5m')
ativo_VALE3 = pd.DataFrame(hist_VALE3)
VALE3_close = ativo_VALE3['close']
VALE3_close.to_excel('VALE3_close.xlsx')

# %%
# FERBASA
FESA3 = Ticker('FESA3.SA')
hist_FESA3 = FESA3.history(period='60d', interval='5m')
ativo_FESA3 = pd.DataFrame(hist_FESA3)
FESA3_close = ativo_FESA3['close']
FESA3_close.to_excel('FESA3_close.xlsx')

FESA4 = Ticker('FESA4.SA')
hist_FESA4 = FESA4.history(period='60d', interval='5m')
ativo_FESA4 = pd.DataFrame(hist_FESA4)
FESA4_close = ativo_FESA4['close']
FESA4_close.to_excel('FESA4_close.xlsx')

# GERDAU
GGBR3 = Ticker('GGBR3.SA')
hist_GGBR3 = GGBR3.history(period='60d', interval='5m')
ativo_GGBR3 = pd.DataFrame(hist_GGBR3)
GGBR3_close = ativo_GGBR3['close']
GGBR3_close.to_excel('GGBR3_close.xlsx')

GGBR4 = Ticker('GGBR4.SA')
hist_GGBR4 = GGBR4.history(period='60d', interval='5m')
ativo_GGBR4 = pd.DataFrame(hist_GGBR4)
GGBR4_close = ativo_GGBR4['close']
GGBR4_close.to_excel('GGBR4_close.xlsx')

# GERDAU MET
GOAU3 = Ticker('GOAU3.SA')
hist_GOAU3 = GOAU3.history(period='60d', interval='5m')
ativo_GOAU3 = pd.DataFrame(hist_GOAU3)
GOAU3_close = ativo_GOAU3['close']
GOAU3_close.to_excel('GOAU3_close.xlsx')

# %%
GOAU4 = Ticker('GOAU4.SA')
hist_GOAU4 = GOAU4.history(period='60d', interval='5m')
ativo_GOAU4 = pd.DataFrame(hist_GOAU4)
GOAU4_close = ativo_GOAU4['close']
GOAU4_close.to_excel('GOAU4_close.xlsx')

# SID NACIONAL
CSNA3 = Ticker('CSNA3.SA')
hist_CSNA3 = CSNA3.history(period='60d', interval='5m')
ativo_CSNA3 = pd.DataFrame(hist_CSNA3)
CSNA3_close = ativo_CSNA3['close']
CSNA3_close.to_excel('CSNA3_close.xlsx')

# USIMINAS
USIM3 = Ticker('USIM3.SA')
hist_USIM3 = USIM3.history(period='60d', interval='5m')
ativo_USIM3 = pd.DataFrame(hist_USIM3)
USIM3_close = ativo_USIM3['close']
USIM3_close.to_excel('USIM3_close.xlsx')

USIM5 = Ticker('USIM5.SA')
hist_USIM5 = USIM5.history(period='60d', interval='5m')
ativo_USIM5 = pd.DataFrame(hist_USIM5)
USIM5_close = ativo_USIM5['close']
USIM5_close.to_excel('USIM5_close.xlsx')

USIM6 = Ticker('USIM6.SA')
hist_USIM6 = USIM6.history(period='60d', interval='5m')
ativo_USIM6 = pd.DataFrame(hist_USIM6)
USIM6_close = ativo_USIM6['close']
USIM6_close.to_excel('USIM6_close.xlsx')

# %%
# MANGELS INDL
MGEL3 = Ticker('MGEL3.SA')
hist_MGEL3 = MGEL3.history(period='60d', interval='5m')
ativo_MGEL3 = pd.DataFrame(hist_MGEL3)
MGEL3_close = ativo_MGEL3['close']
MGEL3_close.to_excel('MGEL3_close.xlsx')

MGEL4 = Ticker('MGEL4.SA')
hist_MGEL4 = MGEL4.history(period='60d', interval='5m')
ativo_MGEL4 = pd.DataFrame(hist_MGEL4)
MGEL4_close = ativo_MGEL4['close']
MGEL4_close.to_excel('MGEL4_close.xlsx')

# PANATLANTICA
PATI3 = Ticker('PATI3.SA')
hist_PATI3 = PATI3.history(period='60d', interval='5m')
ativo_PATI3 = pd.DataFrame(hist_PATI3)
PATI3_close = ativo_PATI3['close']
PATI3_close.to_excel('PATI3_close.xlsx')

PATI4 = Ticker('PATI4.SA')
hist_PATI4 = PATI4.history(period='60d', interval='5m')
ativo_PATI4 = pd.DataFrame(hist_PATI4)
PATI4_close = ativo_MGEL4['close']
PATI4_close.to_excel('PATI4_close.xlsx')

# TEKNO
TKNO3 = Ticker('TKNO3.SA')
hist_TKNO3 = TKNO3.history(period='60d', interval='5m')
ativo_TKNO3 = pd.DataFrame(hist_TKNO3)
TKNO3_close = ativo_TKNO3['close']
TKNO3_close.to_excel('TKNO3_close.xlsx')

# %%
TKNO4 = Ticker('TKNO4.SA')
hist_TKNO4 = TKNO4.history(period='60d', interval='5m')
ativo_TKNO4 = pd.DataFrame(hist_TKNO4)
TKNO4_close = ativo_TKNO4['close']
TKNO4_close.to_excel('TKNO4_close.xlsx')

# PARANAPANEMA
PMAM3 = Ticker('PMAM3.SA')
hist_PMAM3 = PMAM3.history(period='60d', interval='5m')
ativo_PMAM3 = pd.DataFrame(hist_PMAM3)
PMAM3_close = ativo_PMAM3['close']
PMAM3_close.to_excel('PMAM3_close.xlsx')

# BRASKEM
BRKM3 = Ticker('BRKM3.SA')
hist_BRKM3 = BRKM3.history(period='60d', interval='5m')
ativo_BRKM3 = pd.DataFrame(hist_BRKM3)
BRKM3_close = ativo_BRKM3['close']
BRKM3_close.to_excel('BRKM3_close.xlsx')

BRKM5 = Ticker('BRKM5.SA')
hist_BRKM5 = BRKM5.history(period='60d', interval='5m')
ativo_BRKM5 = pd.DataFrame(hist_BRKM5)
BRKM5_close = ativo_BRKM5['close']
BRKM5_close.to_excel('BRKM5_close.xlsx')

BRKM6 = Ticker('BRKM6.SA')
hist_BRKM6 = BRKM6.history(period='60d', interval='5m')
ativo_BRKM6 = pd.DataFrame(hist_BRKM6)
BRKM6_close = ativo_BRKM6['close']
BRKM6_close.to_excel('BRKM6_close.xlsx')

# %%
# DEXXOS PAR
DEXP3 = Ticker('DEXP3.SA')
hist_DEXP3 = DEXP3.history(period='60d', interval='5m')
ativo_DEXP3 = pd.DataFrame(hist_BRKM6)
DEXP3_close = ativo_DEXP3['close']
DEXP3_close.to_excel('DEXP3_close.xlsx')

DEXP4 = Ticker('DEXP4.SA')
hist_DEXP4 = DEXP4.history(period='60d', interval='5m')
ativo_DEXP4 = pd.DataFrame(hist_DEXP4)
DEXP4_close = ativo_DEXP4['close']
DEXP4_close.to_excel('DEXP4_close.xlsx')

# FER HERINGER
FHER3 = Ticker('FHER3.SA')
hist_FHER3 = FHER3.history(period='60d', interval='5m')
ativo_FHER3 = pd.DataFrame(hist_FHER3)
FHER3_close = ativo_FHER3['close']
FHER3_close.to_excel('FHER3_close.xlsx')

# NUTRIPLANT
NUTR3 = Ticker('NUTR3.SA')
hist_NUTR3 = NUTR3.history(period='60d', interval='5m')
ativo_NUTR3 = pd.DataFrame(hist_NUTR3)
NUTR3_close = ativo_NUTR3['close']
NUTR3_close.to_excel('NUTR3_close.xlsx')

# VITTIA
VITT3 = Ticker('VITT3.SA')
hist_VITT3 = VITT3.history(period='60d', interval='5m')
ativo_VITT3 = pd.DataFrame(hist_VITT3)
VITT3_close = ativo_VITT3['close']
VITT3_close.to_excel('VITT3_close.xlsx')

# %%
# CRISTAL
CRPG3 = Ticker('CRPG3.SA')
hist_CRPG3 = CRPG3.history(period='60d', interval='5m')
ativo_CRPG3 = pd.DataFrame(hist_CRPG3)
CRPG3_close = ativo_CRPG3['close']
CRPG3_close.to_excel('CRPG3_close.xlsx')

CRPG5 = Ticker('CRPG5.SA')
hist_CRPG5 = CRPG5.history(period='60d', interval='5m')
ativo_CRPG5 = pd.DataFrame(hist_CRPG5)
CRPG5_close = ativo_CRPG5['close']
CRPG5_close.to_excel('CRPG5_close.xlsx')

CRPG6 = Ticker('CRPG6.SA')
hist_CRPG6 = CRPG6.history(period='60d', interval='5m')
ativo_CRPG6 = pd.DataFrame(hist_CRPG6)
CRPG6_close = ativo_CRPG6['close']
CRPG6_close.to_excel('CRPG6_close.xlsx')

# UNIPAR
UNIP3 = Ticker('UNIP3.SA')
hist_UNIP3 = UNIP3.history(period='60d', interval='5m')
ativo_UNIP3 = pd.DataFrame(hist_UNIP3)
UNIP3_close = ativo_UNIP3['close']
UNIP3_close.to_excel('UNIP3_close.xlsx')

UNIP5 = Ticker('UNIP5.SA')
hist_UNIP5 = UNIP5.history(period='60d', interval='5m')
ativo_UNIP5 = pd.DataFrame(hist_UNIP5)
UNIP5_close = ativo_UNIP5['close']
UNIP5_close.to_excel('UNIP5_close.xlsx')

# %%
UNIP6 = Ticker('UNIP6.SA')
hist_UNIP6 = UNIP6.history(period='60d', interval='5m')
ativo_UNIP6 = pd.DataFrame(hist_UNIP6)
UNIP6_close = ativo_UNIP6['close']
UNIP6_close.to_excel('UNIP6_close.xlsx')

# DEXCO
DXCO3 = Ticker('DXCO3.SA')
hist_DXCO3 = DXCO3.history(period='60d', interval='5m')
ativo_DXCO3 = pd.DataFrame(hist_DXCO3)
DXCO3_close = ativo_DXCO3['close']
DXCO3_close.to_excel('DXCO3_close.xlsx')

# EUCATEX
EUCA4 = Ticker('EUCA4.SA')
hist_EUCA4 = EUCA4.history(period='60d', interval='5m')
ativo_EUCA4 = pd.DataFrame(hist_EUCA4)
EUCA4_close = ativo_EUCA4['close']
EUCA4_close.to_excel('EUCA4_close.xlsx')

EUCA3 = Ticker('EUCA3.SA')
hist_EUCA3 = EUCA3.history(period='60d', interval='5m')
ativo_EUCA3 = pd.DataFrame(hist_EUCA3)
EUCA3_close = ativo_EUCA3['close']
EUCA3_close.to_excel('EUCA3_close.xlsx')

# KLABIN S/A
KLBN3 = Ticker('KLBN3.SA')
hist_KLBN3 = KLBN3.history(period='60d', interval='5m')
ativo_KLBN3 = pd.DataFrame(hist_KLBN3)
KLBN3_close = ativo_KLBN3['close']
KLBN3_close.to_excel('KLBN3_close.xlsx')

# %%
KLBN4 = Ticker('KLBN4.SA')
hist_KLBN4 = KLBN4.history(period='60d', interval='5m')
ativo_KLBN4 = pd.DataFrame(hist_KLBN4)
KLBN4_close = ativo_KLBN4['close']
KLBN4_close.to_excel('KLBN4_close.xlsx')

KLBN11 = Ticker('KLBN11.SA')
hist_KLBN11 = KLBN11.history(period='60d', interval='5m')
ativo_KLBN11 = pd.DataFrame(hist_KLBN11)
KLBN11_close = ativo_KLBN11['close']
KLBN11_close.to_excel('KLBN11_close.xlsx')

# MELHOR SP
#MSPA4 = Ticker('MSPA4.SA')
#hist_MSPA4 = MSPA4.history(period='60d', interval='5m')
#ativo_MSPA4 = pd.DataFrame(hist_MSPA4)
#MSPA4_close = ativo_MSPA4['close']
#MSPA4_close.to_excel('MSPA4_close.xlsx')

# SUZANO S.A.
SUZB3 = Ticker('SUZB3.SA')
hist_SUZB3 = SUZB3.history(period='60d', interval='5m')
ativo_SUZB3 = pd.DataFrame(hist_SUZB3)
SUZB3_close = ativo_SUZB3['close']
SUZB3_close.to_excel('SUZB3_close.xlsx')

# IRANI
RANI3 = Ticker('RANI3.SA')
hist_RANI3 = RANI3.history(period='60d', interval='5m')
ativo_RANI3 = pd.DataFrame(hist_RANI3)
RANI3_close = ativo_RANI3['close']
RANI3_close.to_excel('RANI3_close.xlsx')

# %%
# METAL IGUACU
MTIG3 = Ticker('MTIG3.SA')
hist_MTIG3 = MTIG3.history(period='60d', interval='5m')
ativo_MTIG3 = pd.DataFrame(hist_MTIG3)
MTIG3_close = ativo_MTIG3['close']
MTIG3_close.to_excel('MTIG3_close.xlsx')

MTIG4 = Ticker('MTIG4.SA')
hist_MTIG4 = MTIG4.history(period='60d', interval='5m')
ativo_MTIG4 = pd.DataFrame(hist_MTIG4)
MTIG4_close = ativo_MTIG4['close']
MTIG4_close.to_excel('MTIG4_close.xlsx')

# SANSUY
SNSY3 = Ticker('SNSY3.SA')
hist_SNSY3 = SNSY3.history(period='60d', interval='5m')
ativo_SNSY3 = pd.DataFrame(hist_SNSY3)
SNSY3_close = ativo_SNSY3['close']
SNSY3_close.to_excel('SNSY3_close.xlsx')

SNSY5 = Ticker('SNSY5.SA')
hist_SNSY5 = SNSY5.history(period='60d', interval='5m')
ativo_SNSY5 = pd.DataFrame(hist_SNSY5)
SNSY5_close = ativo_MTIG4['close']
SNSY5_close.to_excel('SNSY5_close.xlsx')
