# %%
### SCRIPT PARA OBTER HISTORICO DE COTACAO DAS ACOES B3.
#
### ATE 15/09/2022 (site B3) 482 EMPRESAS COM ACOES NEGOCIAVEIS NO MERCADO A VISTA.
#
### CRITERIO DE SELECAO DOS TICKERS NEGOCIAVEIS.
### ATIVOS PERTENCENTES AOS SEGUIMENTOS NOVO MERCADO (NM),
### CIA. NIVEL 1 E 2 DE GOVERNANCA CORPORATIVA (N1 E N2),
### TRADICIONAL-BOLSA (EXCLUINDO DRE), BOVESPA MAIS (MA)
### E BOVESPA MAIS NIVEL 2 (M2).
 
###########################################################
# ROTINA PARA IMPORTAR O HISTORICO DE COTACAO DOS TICKERS #
###########################################################

# INSTALAR O YAHOO QUERY

# !pip install yahooquery

# (SE NECESSARIO) INSTALAR LEITOR DE ARQUIVO XLS

# !pip install xlrd

# INICIALIZAR OS MODULOS YAHOOQUERY

import yahooquery as yq
from yahooquery import Ticker

# INICIALIZAR OS MODULOS AUXILIARES

import pandas as pd
import requests as rq
import numpy as ny

###########################################################
# IMPORTAR HISTORICO DE COTACAO DOS ATIVOS SELECIONADOS   #
# OS CODIGOS SERAO DIVIDIDOS POR SETOR ECONOMICO          #
###########################################################

# %%
### 5 ###
########################################
### SETOR ECONOMICO: CONSUMO CICLICO ###
########################################

# ALPHAVILLE
AVLL3 = Ticker('AVLL3.SA')
hist_AVLL3 = AVLL3.history(period='60d', interval='5m')
ativo_AVLL3 = pd.DataFrame(hist_AVLL3)
AVLL3_close = ativo_AVLL3['close']
AVLL3_close.to_excel('AVLL3_close.xlsx')

# CONST A LIND
CALI3 = Ticker('CALI3.SA')
hist_CALI3 = CALI3.history(period='60d', interval='5m')
ativo_CALI3 = pd.DataFrame(hist_CALI3)
CALI3_close = ativo_CALI3['close']
CALI3_close.to_excel('CALI3_close.xlsx')

# CR2         
CRDE3 = Ticker('CRDE3.SA')
hist_CRDE3 = CRDE3.history(period='60d', interval='5m')
ativo_CRDE3 = pd.DataFrame(hist_CRDE3)
CRDE3_close = ativo_CRDE3['close']
CRDE3_close.to_excel('CRDE3_close.xlsx')

# CURY S/A
CURY3 = Ticker('CURY3.SA')
hist_CURY3 = CURY3.history(period='60d', interval='5m')
ativo_CURY3 = pd.DataFrame(hist_CURY3)
CURY3_close = ativo_CURY3['close']
CURY3_close.to_excel('CURY3_close.xlsx')

# CYRELA REALT
CYRE3 = Ticker('CYRE3.SA')
hist_CYRE3 = CYRE3.history(period='60d', interval='5m')
ativo_CYRE3 = pd.DataFrame(hist_CYRE3)
CYRE3_close = ativo_CYRE3['close']
CYRE3_close.to_excel('CYRE3_close.xlsx')

# DIRECIONAL  
DIRR3 = Ticker('DIRR3.SA')
hist_DIRR3 = DIRR3.history(period='60d', interval='5m')
ativo_DIRR3 = pd.DataFrame(hist_DIRR3)
DIRR3_close = ativo_DIRR3['close']
DIRR3_close.to_excel('DIRR3_close.xlsx')

# EVEN
EVEN3 = Ticker('EVEN3.SA')
hist_EVEN3 = EVEN3.history(period='60d', interval='5m')
ativo_EVEN3 = pd.DataFrame(hist_EVEN3)
EVEN3_close = ativo_EVEN3['close']
EVEN3_close.to_excel('EVEN3_close.xlsx')

# EZTEC       
EZTC3 = Ticker('EZTC3.SA')
hist_EZTC3 = EZTC3.history(period='60d', interval='5m')
ativo_EZTC3 = pd.DataFrame(hist_EZTC3)
EZTC3_close = ativo_EZTC3['close']
EZTC3_close.to_excel('EZTC3_close.xlsx')

# GAFISA      
GFSA3 = Ticker('GFSA3.SA')
hist_GFSA3 = GFSA3.history(period='60d', interval='5m')
ativo_GFSA3 = pd.DataFrame(hist_GFSA3)
GFSA3_close = ativo_GFSA3['close']
GFSA3_close.to_excel('GFSA3_close.xlsx')

# HELBOR      
HBOR3 = Ticker('HBOR3.SA')
hist_HBOR3 = HBOR3.history(period='60d', interval='5m')
ativo_HBOR3 = pd.DataFrame(hist_HBOR3)
HBOR3_close = ativo_HBOR3['close']
HBOR3_close.to_excel('HBOR3_close.xlsx')

# JHSF PART
JHSF3 = Ticker('JHSF3.SA')
hist_JHSF3 = JHSF3.history(period='60d', interval='5m')
ativo_JHSF3 = pd.DataFrame(hist_JHSF3)
JHSF3_close = ativo_JHSF3['close']
JHSF3_close.to_excel('JHSF3_close.xlsx')

# JOAO FORTES 
JFEN3 = Ticker('JFEN3.SA')
hist_JFEN3 = JFEN3.history(period='60d', interval='5m')
ativo_JFEN3 = pd.DataFrame(hist_JFEN3)
JFEN3_close = ativo_JFEN3['close']
JFEN3_close.to_excel('JFEN3_close.xlsx')

# KALLAS
#KLAS3 = Ticker('KLAS3.SA')
#hist_KLAS3 = KLAS3.history(period='60d', interval='5m')
#ativo_KLAS3 = pd.DataFrame(hist_KLAS3)
#KLAS3_close = ativo_KLAS3['close']
#KLAS3_close.to_excel('KLAS3_close.xlsx')

# LAVVI
LAVV3 = Ticker('LAVV3.SA')
hist_LAVV3 = LAVV3.history(period='60d', interval='5m')
ativo_LAVV3 = pd.DataFrame(hist_LAVV3)
LAVV3_close = ativo_LAVV3['close']
LAVV3_close.to_excel('LAVV3_close.xlsx')

# MELNICK
MELK3 = Ticker('MELK3.SA')
hist_MELK3 = MELK3.history(period='60d', interval='5m')
ativo_MELK3 = pd.DataFrame(hist_MELK3)
MELK3_close = ativo_MELK3['close']
MELK3_close.to_excel('MELK3_close.xlsx')

# MITRE REALTY
MTRE3 = Ticker('MTRE3.SA')
hist_MTRE3 = MTRE3.history(period='60d', interval='5m')
ativo_MTRE3 = pd.DataFrame(hist_MTRE3)
MTRE3_close = ativo_MTRE3['close']
MTRE3_close.to_excel('MTRE3_close.xlsx')

# MOURA DUBEUX
MDNE3 = Ticker('MDNE3.SA')
hist_MDNE3 = MDNE3.history(period='60d', interval='5m')
ativo_MDNE3 = pd.DataFrame(hist_MDNE3)
MDNE3_close = ativo_MDNE3['close']
MDNE3_close.to_excel('MDNE3_close.xlsx')

# MRV         
MRVE3 = Ticker('MRVE3.SA')
hist_MRVE3 = MRVE3.history(period='60d', interval='5m')
ativo_MRVE3 = pd.DataFrame(hist_MRVE3)
MRVE3_close = ativo_MRVE3['close']
MRVE3_close.to_excel('MRVE3_close.xlsx')

# PDG REALT   
PDGR3 = Ticker('PDGR3.SA')
hist_PDGR3 = PDGR3.history(period='60d', interval='5m')
ativo_PDGR3 = pd.DataFrame(hist_PDGR3)
PDGR3_close = ativo_PDGR3['close']
PDGR3_close.to_excel('PDGR3_close.xlsx')

# PLANOEPLANO
PLPL3 = Ticker('PLPL3.SA')
hist_PLPL3 = PLPL3.history(period='60d', interval='5m')
ativo_PLPL3 = pd.DataFrame(hist_PLPL3)
PLPL3_close = ativo_PLPL3['close']
PLPL3_close.to_excel('PLPL3_close.xlsx')

# RNI
RDNI3 = Ticker('RDNI3.SA')
hist_RDNI3 = RDNI3.history(period='60d', interval='5m')
ativo_RDNI3 = pd.DataFrame(hist_RDNI3)
RDNI3_close = ativo_RDNI3['close']
RDNI3_close.to_excel('RDNI3_close.xlsx')

# ROSSI RESID
RSID3 = Ticker('RSID3.SA')
hist_RSID3 = RSID3.history(period='60d', interval='5m')
ativo_RSID3 = pd.DataFrame(hist_RSID3)
RSID3_close = ativo_RSID3['close']
RSID3_close.to_excel('RSID3_close.xlsx')

# TECNISA     
TCSA3 = Ticker('TCSA3.SA')
hist_TCSA3 = TCSA3.history(period='60d', interval='5m')
ativo_TCSA3 = pd.DataFrame(hist_TCSA3)
TCSA3_close = ativo_TCSA3['close']
TCSA3_close.to_excel('TCSA3_close.xlsx')

# TENDA
TEND3 = Ticker('TEND3.SA')
hist_TEND3 = TEND3.history(period='60d', interval='5m')
ativo_TEND3 = pd.DataFrame(hist_TEND3)
TEND3_close = ativo_TEND3['close']
TEND3_close.to_excel('TEND3_close.xlsx')

# TRISUL
TRIS3 = Ticker('TRIS3.SA')
hist_TRIS3 = TRIS3.history(period='60d', interval='5m')
ativo_TRIS3 = pd.DataFrame(hist_TRIS3)
TRIS3_close = ativo_TRIS3['close']
TRIS3_close.to_excel('TRIS3_close.xlsx')

# VIVER       
VIVR3 = Ticker('VIVR3.SA')
hist_VIVR3 = VIVR3.history(period='60d', interval='5m')
ativo_VIVR3 = pd.DataFrame(hist_VIVR3)
VIVR3_close = ativo_VIVR3['close']
VIVR3_close.to_excel('VIVR3_close.xlsx')

# CEDRO
CEDO3 = Ticker('CEDO3.SA')
hist_CEDO3 = CEDO3.history(period='60d', interval='5m')
ativo_CEDO3 = pd.DataFrame(hist_CEDO3)
CEDO3_close = ativo_CEDO3['close']
CEDO3_close.to_excel('CEDO3_close.xlsx')

CEDO4 = Ticker('CEDO4.SA')
hist_CEDO4 = CEDO4.history(period='60d', interval='5m')
ativo_CEDO4 = pd.DataFrame(hist_CEDO4)
CEDO4_close = ativo_CEDO4['close']
CEDO4_close.to_excel('CEDO4_close.xlsx')

# COTEMINAS   
CTNM3 = Ticker('CTNM3.SA')
hist_CTNM3 = CTNM3.history(period='60d', interval='5m')
ativo_CTNM3 = pd.DataFrame(hist_CTNM3)
CTNM3_close = ativo_CTNM3['close']
CTNM3_close.to_excel('CTNM3_close.xlsx')

CTNM4 = Ticker('CTNM4.SA')
hist_CTNM4 = CTNM4.history(period='60d', interval='5m')
ativo_CTNM4 = pd.DataFrame(hist_CTNM4)
CTNM4_close = ativo_CTNM4['close']
CTNM4_close.to_excel('CTNM4_close.xlsx')

# DOHLER
DOHL3 = Ticker('DOHL3.SA')
hist_DOHL3 = DOHL3.history(period='60d', interval='5m')
ativo_DOHL3 = pd.DataFrame(hist_DOHL3)
DOHL3_close = ativo_DOHL3['close']
DOHL3_close.to_excel('DOHL3_close.xlsx')

DOHL4 = Ticker('DOHL4.SA')
hist_DOHL4 = DOHL4.history(period='60d', interval='5m')
ativo_DOHL4 = pd.DataFrame(hist_DOHL4)
DOHL4_close = ativo_DOHL4['close']
DOHL4_close.to_excel('DOHL4_close.xlsx')

# KARSTEN     
CTKA3 = Ticker('CTKA3.SA')
hist_CTKA3 = CTKA3.history(period='60d', interval='5m')
ativo_CTKA3 = pd.DataFrame(hist_CTKA3)
CTKA3_close = ativo_CTKA3['close']
CTKA3_close.to_excel('CTKA3_close.xlsx')

CTKA4 = Ticker('CTKA4.SA')
hist_CTKA4 = CTKA4.history(period='60d', interval='5m')
ativo_CTKA4 = pd.DataFrame(hist_CTKA4)
CTKA4_close = ativo_CTKA4['close']
CTKA4_close.to_excel('CTKA4_close.xlsx')

# PETTENATI   
PTNT3 = Ticker('PTNT3.SA')
hist_PTNT3 = PTNT3.history(period='60d', interval='5m')
ativo_PTNT3 = pd.DataFrame(hist_PTNT3)
PTNT3_close = ativo_PTNT3['close']
PTNT3_close.to_excel('PTNT3_close.xlsx')

PTNT4 = Ticker('PTNT4.SA')
hist_PTNT4 = PTNT4.history(period='60d', interval='5m')
ativo_PTNT4 = pd.DataFrame(hist_PTNT4)
PTNT4_close = ativo_PTNT4['close']
PTNT4_close.to_excel('PTNT4_close.xlsx')

# SANTANENSE
CTSA3 = Ticker('CTSA3.SA')
hist_CTSA3 = CTSA3.history(period='60d', interval='5m')
ativo_CTSA3 = pd.DataFrame(hist_CTSA3)
CTSA3_close = ativo_CTSA3['close']
CTSA3_close.to_excel('CTSA3_close.xlsx')

CTSA4 = Ticker('CTSA4.SA')
hist_CTSA4 = CTSA4.history(period='60d', interval='5m')
ativo_CTSA4 = pd.DataFrame(hist_CTSA4)
CTSA4_close = ativo_CTSA4['close']
CTSA4_close.to_excel('CTSA4_close.xlsx')

# SPRINGS     
SGPS3 = Ticker('SGPS3.SA')
hist_SGPS3 = SGPS3.history(period='60d', interval='5m')
ativo_SGPS3 = pd.DataFrame(hist_SGPS3)
SGPS3_close = ativo_SGPS3['close']
SGPS3_close.to_excel('SGPS3_close.xlsx')

# TEKA        
TEKA4 = Ticker('TEKA4.SA')
hist_TEKA4 = TEKA4.history(period='60d', interval='5m')
ativo_TEKA4 = pd.DataFrame(hist_TEKA4)
TEKA4_close = ativo_TEKA4['close']
TEKA4_close.to_excel('TEKA4_close.xlsx')

# TEX RENAUX  
TXRX3 = Ticker('TXRX3.SA')
hist_TXRX3 = TXRX3.history(period='60d', interval='5m')
ativo_TXRX3 = pd.DataFrame(hist_TXRX3)
TXRX3_close = ativo_TXRX3['close']
TXRX3_close.to_excel('TXRX3_close.xlsx')

TXRX4 = Ticker('TXRX4.SA')
hist_TXRX4 = TXRX4.history(period='60d', interval='5m')
ativo_TXRX4 = pd.DataFrame(hist_TXRX4)
TXRX4_close = ativo_TXRX4['close']
TXRX4_close.to_excel('TXRX4_close.xlsx')

# TRACK FIELD
TFCO4 = Ticker('TFCO4.SA')
hist_TFCO4 = TFCO4.history(period='60d', interval='5m')
ativo_TFCO4 = pd.DataFrame(hist_TFCO4)
TFCO4_close = ativo_TFCO4['close']
TFCO4_close.to_excel('TFCO4_close.xlsx')

# ALPARGATAS  
ALPA3 = Ticker('ALPA3.SA')
hist_ALPA3 = ALPA3.history(period='60d', interval='5m')
ativo_ALPA3 = pd.DataFrame(hist_ALPA3)
ALPA3_close = ativo_ALPA3['close']
ALPA3_close.to_excel('ALPA3_close.xlsx')

ALPA4 = Ticker('ALPA4.SA')
hist_ALPA4 = ALPA4.history(period='60d', interval='5m')
ativo_ALPA4 = pd.DataFrame(hist_ALPA4)
ALPA4_close = ativo_ALPA4['close']
ALPA4_close.to_excel('ALPA4_close.xlsx')

# CAMBUCI     
CAMB3 = Ticker('CAMB3.SA')
hist_CAMB3 = CAMB3.history(period='60d', interval='5m')
ativo_CAMB3 = pd.DataFrame(hist_CAMB3)
CAMB3_close = ativo_CAMB3['close']
CAMB3_close.to_excel('CAMB3_close.xlsx')

# GRENDENE    
GRND3 = Ticker('GRND3.SA')
hist_GRND3 = GRND3.history(period='60d', interval='5m')
ativo_GRND3 = pd.DataFrame(hist_GRND3)
GRND3_close = ativo_GRND3['close']
GRND3_close.to_excel('GRND3_close.xlsx')

# VULCABRAS
VULC3 = Ticker('VULC3.SA')
hist_VULC3 = VULC3.history(period='60d', interval='5m')
ativo_VULC3 = pd.DataFrame(hist_VULC3)
VULC3_close = ativo_VULC3['close']
VULC3_close.to_excel('VULC3_close.xlsx')

# MUNDIAL
MNDL3 = Ticker('MNDL3.SA')
hist_MNDL3 = MNDL3.history(period='60d', interval='5m')
ativo_MNDL3 = pd.DataFrame(hist_MNDL3)
MNDL3_close = ativo_MNDL3['close']
MNDL3_close.to_excel('MNDL3_close.xlsx')

# TECHNOS
TECN3 = Ticker('TECN3.SA')
hist_TECN3 = TECN3.history(period='60d', interval='5m')
ativo_TECN3 = pd.DataFrame(hist_TECN3)
TECN3_close = ativo_TECN3['close']
TECN3_close.to_excel('TECN3_close.xlsx')

# VIVARA S.A.
VIVA3 = Ticker('VIVA3.SA')
hist_VIVA3 = VIVA3.history(period='60d', interval='5m')
ativo_VIVA3 = pd.DataFrame(hist_VIVA3)
VIVA3_close = ativo_VIVA3['close']
VIVA3_close.to_excel('VIVA3_close.xlsx')

# WHIRLPOOL
WHRL3 = Ticker('WHRL3.SA')
hist_WHRL3 = WHRL3.history(period='60d', interval='5m')
ativo_WHRL3 = pd.DataFrame(hist_WHRL3)
WHRL3_close = ativo_WHRL3['close']
WHRL3_close.to_excel('WHRL3_close.xlsx')

WHRL4 = Ticker('WHRL4.SA')
hist_WHRL4 = WHRL4.history(period='60d', interval='5m')
ativo_WHRL4 = pd.DataFrame(hist_WHRL4)
WHRL4_close = ativo_WHRL4['close']
WHRL4_close.to_excel('WHRL4_close.xlsx')

# UNICASA
UCAS3 = Ticker('UCAS3.SA')
hist_UCAS3 = UCAS3.history(period='60d', interval='5m')
ativo_UCAS3 = pd.DataFrame(hist_UCAS3)
UCAS3_close = ativo_UCAS3['close']
UCAS3_close.to_excel('UCAS3_close.xlsx')

# HERCULES    
#HETA3 = Ticker('HETA3.SA')
#hist_HETA3 = HETA3.history(period='60d', interval='5m')
#ativo_HETA3 = pd.DataFrame(hist_HETA3)
#HETA3_close = ativo_HETA3['close']
#HETA3_close.to_excel('HETA3_close.xlsx')

HETA4 = Ticker('HETA4.SA')
hist_HETA4 = HETA4.history(period='60d', interval='5m')
ativo_HETA4 = pd.DataFrame(hist_HETA4)
HETA4_close = ativo_HETA4['close']
HETA4_close.to_excel('HETA4_close.xlsx')

# IOCHP-MAXION
MYPK3 = Ticker('MYPK3.SA')
hist_MYPK3 = MYPK3.history(period='60d', interval='5m')
ativo_MYPK3 = pd.DataFrame(hist_MYPK3)
MYPK3_close = ativo_MYPK3['close']
MYPK3_close.to_excel('MYPK3_close.xlsx')

# METAL LEVE  
LEVE3 = Ticker('LEVE3.SA')
hist_LEVE3 = LEVE3.history(period='60d', interval='5m')
ativo_LEVE3 = pd.DataFrame(hist_LEVE3)
LEVE3_close = ativo_LEVE3['close']
LEVE3_close.to_excel('LEVE3_close.xlsx')

# PLASCAR PART
PLAS3 = Ticker('PLAS3.SA')
hist_PLAS3 = PLAS3.history(period='60d', interval='5m')
ativo_PLAS3 = pd.DataFrame(hist_PLAS3)
PLAS3_close = ativo_PLAS3['close']
PLAS3_close.to_excel('PLAS3_close.xlsx')

#PLAS11 = Ticker('PLAS11.SA')
#hist_PLAS11 = PLAS11.history(period='60d', interval='5m')
#ativo_PLAS11 = pd.DataFrame(hist_PLAS11)
#PLAS11_close = ativo_PLAS11['close']
#PLAS11_close.to_excel('PLAS11_close.xlsx')

# HOTEIS OTHON
HOOT3 = Ticker('HOOT3.SA')
hist_HOOT3 = HOOT3.history(period='60d', interval='5m')
ativo_HOOT3 = pd.DataFrame(hist_HOOT3)
HOOT3_close = ativo_HOOT3['close']
HOOT3_close.to_excel('HOOT3_close.xlsx')

HOOT4 = Ticker('HOOT4.SA')
hist_HOOT4 = HOOT4.history(period='60d', interval='5m')
ativo_HOOT4 = pd.DataFrame(hist_HOOT4)
HOOT4_close = ativo_HOOT4['close']
HOOT4_close.to_excel('HOOT4_close.xlsx')

# BK BRASIL
BKBR3 = Ticker('BKBR3.SA')
hist_BKBR3 = BKBR3.history(period='60d', interval='5m')
ativo_BKBR3 = pd.DataFrame(hist_BKBR3)
BKBR3_close = ativo_BKBR3['close']
BKBR3_close.to_excel('BKBR3_close.xlsx')

# IMC S/A
MEAL3 = Ticker('MEAL3.SA')
hist_MEAL3 = MEAL3.history(period='60d', interval='5m')
ativo_MEAL3 = pd.DataFrame(hist_MEAL3)
MEAL3_close = ativo_MEAL3['close']
MEAL3_close.to_excel('MEAL3_close.xlsx')

# BIC MONARK
BMKS3 = Ticker('BMKS3.SA')
hist_BMKS3 = BMKS3.history(period='60d', interval='5m')
ativo_BMKS3 = pd.DataFrame(hist_BMKS3)
BMKS3_close = ativo_BMKS3['close']
BMKS3_close.to_excel('BMKS3_close.xlsx')

# ESTRELA
ESTR4 = Ticker('ESTR4.SA')
hist_ESTR4 = ESTR4.history(period='60d', interval='5m')
ativo_ESTR4 = pd.DataFrame(hist_ESTR4)
ESTR4_close = ativo_ESTR4['close']
ESTR4_close.to_excel('ESTR4_close.xlsx')

# SPTURIS     
AHEB3 = Ticker('AHEB3.SA')
hist_AHEB3 = AHEB3.history(period='60d', interval='5m')
ativo_AHEB3 = pd.DataFrame(hist_AHEB3)
AHEB3_close = ativo_AHEB3['close']
AHEB3_close.to_excel('AHEB3_close.xlsx')

AHEB6 = Ticker('AHEB6.SA')
hist_AHEB6 = AHEB6.history(period='60d', interval='5m')
ativo_AHEB6 = pd.DataFrame(hist_AHEB6)
AHEB6_close = ativo_AHEB6['close']
AHEB6_close.to_excel('AHEB6_close.xlsx')

# TIME FOR FUN
SHOW3 = Ticker('SHOW3.SA')
hist_SHOW3 = SHOW3.history(period='60d', interval='5m')
ativo_SHOW3 = pd.DataFrame(hist_SHOW3)
SHOW3_close = ativo_SHOW3['close']
SHOW3_close.to_excel('SHOW3_close.xlsx')

# CVC BRASIL
CVCB3 = Ticker('CVCB3.SA')
hist_CVCB3 = CVCB3.history(period='60d', interval='5m')
ativo_CVCB3 = pd.DataFrame(hist_CVCB3)
CVCB3_close = ativo_CVCB3['close']
CVCB3_close.to_excel('CVCB3_close.xlsx')

# SMART FIT
SMFT3 = Ticker('SMFT3.SA')
hist_SMFT3 = SMFT3.history(period='60d', interval='5m')
ativo_SMFT3 = pd.DataFrame(hist_SMFT3)
SMFT3_close = ativo_SMFT3['close']
SMFT3_close.to_excel('SMFT3_close.xlsx')

# ANIMA
ANIM3 = Ticker('ANIM3.SA')
hist_ANIM3 = ANIM3.history(period='60d', interval='5m')
ativo_ANIM3 = pd.DataFrame(hist_ANIM3)
ANIM3_close = ativo_ANIM3['close']
ANIM3_close.to_excel('ANIM3_close.xlsx')

# BAHEMA      
BAHI3 = Ticker('BAHI3.SA')
hist_BAHI3 = BAHI3.history(period='60d', interval='5m')
ativo_BAHI3 = pd.DataFrame(hist_BAHI3)
BAHI3_close = ativo_BAHI3['close']
BAHI3_close.to_excel('BAHI3_close.xlsx')

# COGNA ON
COGN3 = Ticker('COGN3.SA')
hist_COGN3 = COGN3.history(period='60d', interval='5m')
ativo_COGN3 = pd.DataFrame(hist_COGN3)
COGN3_close = ativo_COGN3['close']
COGN3_close.to_excel('COGN3_close.xlsx')

# CRUZEIRO EDU
CSED3 = Ticker('CSED3.SA')
hist_CSED3 = CSED3.history(period='60d', interval='5m')
ativo_CSED3 = pd.DataFrame(hist_CSED3)
CSED3_close = ativo_CSED3['close']
CSED3_close.to_excel('CSED3_close.xlsx')

# SER EDUCA
SEER3 = Ticker('SEER3.SA')
hist_SEER3 = SEER3.history(period='60d', interval='5m')
ativo_SEER3 = pd.DataFrame(hist_SEER3)
SEER3_close = ativo_SEER3['close']
SEER3_close.to_excel('SEER3_close.xlsx')

# YDUQS PART
YDUQ3 = Ticker('YDUQ3.SA')
hist_YDUQ3 = YDUQ3.history(period='60d', interval='5m')
ativo_YDUQ3 = pd.DataFrame(hist_YDUQ3)
YDUQ3_close = ativo_YDUQ3['close']
YDUQ3_close.to_excel('YDUQ3_close.xlsx')

# LOCALIZA    
RENT3 = Ticker('RENT3.SA')
hist_RENT3 = RENT3.history(period='60d', interval='5m')
ativo_RENT3 = pd.DataFrame(hist_RENT3)
RENT3_close = ativo_RENT3['close']
RENT3_close.to_excel('RENT3_close.xlsx')

# MOVIDA
MOVI3 = Ticker('MOVI3.SA')
hist_MOVI3 = MOVI3.history(period='60d', interval='5m')
ativo_MOVI3 = pd.DataFrame(hist_MOVI3)
MOVI3_close = ativo_MOVI3['close']
MOVI3_close.to_excel('MOVI3_close.xlsx')

# VAMOS
VAMO3 = Ticker('VAMO3.SA')
hist_VAMO3 = VAMO3.history(period='60d', interval='5m')
ativo_VAMO3 = pd.DataFrame(hist_VAMO3)
VAMO3_close = ativo_VAMO3['close']
VAMO3_close.to_excel('VAMO3_close.xlsx')

# DOTZ SA
DOTZ3 = Ticker('DOTZ3.SA')
hist_DOTZ3 = DOTZ3.history(period='60d', interval='5m')
ativo_DOTZ3 = pd.DataFrame(hist_DOTZ3)
DOTZ3_close = ativo_DOTZ3['close']
DOTZ3_close.to_excel('DOTZ3_close.xlsx')

# AREZZO CO   
ARZZ3 = Ticker('ARZZ3.SA')
hist_ARZZ3 = ARZZ3.history(period='60d', interval='5m')
ativo_ARZZ3 = pd.DataFrame(hist_ARZZ3)
ARZZ3_close = ativo_ARZZ3['close']
ARZZ3_close.to_excel('ARZZ3_close.xlsx')

# CEA MODAS
CEAB3 = Ticker('CEAB3.SA')
hist_CEAB3 = CEAB3.history(period='60d', interval='5m')
ativo_CEAB3 = pd.DataFrame(hist_CEAB3)
CEAB3_close = ativo_CEAB3['close']
CEAB3_close.to_excel('CEAB3_close.xlsx')

# GRAZZIOTIN
CGRA3 = Ticker('CGRA3.SA')
hist_CGRA3 = CGRA3.history(period='60d', interval='5m')
ativo_CGRA3 = pd.DataFrame(hist_CGRA3)
CGRA3_close = ativo_CGRA3['close']
CGRA3_close.to_excel('CGRA3_close.xlsx')

CGRA4 = Ticker('CGRA4.SA')
hist_CGRA4 = CGRA4.history(period='60d', interval='5m')
ativo_CGRA4 = pd.DataFrame(hist_CGRA4)
CGRA4_close = ativo_CGRA4['close']
CGRA4_close.to_excel('CGRA4_close.xlsx')

# GRUPO SOMA
SOMA3 = Ticker('SOMA3.SA')
hist_SOMA3 = SOMA3.history(period='60d', interval='5m')
ativo_SOMA3 = pd.DataFrame(hist_SOMA3)
SOMA3_close = ativo_SOMA3['close']
SOMA3_close.to_excel('SOMA3_close.xlsx')

# GUARARAPES  
GUAR3 = Ticker('GUAR3.SA')
hist_GUAR3 = GUAR3.history(period='60d', interval='5m')
ativo_GUAR3 = pd.DataFrame(hist_GUAR3)
GUAR3_close = ativo_GUAR3['close']
GUAR3_close.to_excel('GUAR3_close.xlsx')

# LE LIS BLANC
LLIS3 = Ticker('LLIS3.SA')
hist_LLIS3 = LLIS3.history(period='60d', interval='5m')
ativo_LLIS3 = pd.DataFrame(hist_LLIS3)
LLIS3_close = ativo_LLIS3['close']
LLIS3_close.to_excel('LLIS3_close.xlsx')

# LOJAS MARISA
AMAR3 = Ticker('AMAR3.SA')
hist_AMAR3 = AMAR3.history(period='60d', interval='5m')
ativo_AMAR3 = pd.DataFrame(hist_AMAR3)
AMAR3_close = ativo_AMAR3['close']
AMAR3_close.to_excel('AMAR3_close.xlsx')

# LOJAS RENNER
LREN3 = Ticker('LREN3.SA')
hist_LREN3 = LREN3.history(period='60d', interval='5m')
ativo_LREN3 = pd.DataFrame(hist_LREN3)
LREN3_close = ativo_LREN3['close']
LREN3_close.to_excel('LREN3_close.xlsx')

# ALLIED
ALLD3 = Ticker('ALLD3.SA')
hist_ALLD3 = ALLD3.history(period='60d', interval='5m')
ativo_ALLD3 = pd.DataFrame(hist_ALLD3)
ALLD3_close = ativo_ALLD3['close']
ALLD3_close.to_excel('ALLD3_close.xlsx')

# MAGAZ LUIZA
MGLU3 = Ticker('MGLU3.SA')
hist_MGLU3 = MGLU3.history(period='60d', interval='5m')
ativo_MGLU3 = pd.DataFrame(hist_MGLU3)
MGLU3_close = ativo_MGLU3['close']
MGLU3_close.to_excel('MGLU3_close.xlsx')

# VIA
VIIA3 = Ticker('VIIA3.SA')
hist_VIIA3 = VIIA3.history(period='60d', interval='5m')
ativo_VIIA3 = pd.DataFrame(hist_VIIA3)
VIIA3_close = ativo_VIIA3['close']
VIIA3_close.to_excel('VIIA3_close.xlsx')

# AMERICANAS
AMER3 = Ticker('AMER3.SA')
hist_AMER3 = AMER3.history(period='60d', interval='5m')
ativo_AMER3 = pd.DataFrame(hist_AMER3)
AMER3_close = ativo_AMER3['close']
AMER3_close.to_excel('AMER3_close.xlsx')

# ESPACOLASER
ESPA3 = Ticker('ESPA3.SA')
hist_ESPA3 = ESPA3.history(period='60d', interval='5m')
ativo_ESPA3 = pd.DataFrame(hist_ESPA3)
ESPA3_close = ativo_ESPA3['close']
ESPA3_close.to_excel('ESPA3_close.xlsx')

ESPA9 = Ticker('ESPA9.SA')
hist_ESPA9 = ESPA9.history(period='60d', interval='5m')
ativo_ESPA9 = pd.DataFrame(hist_ESPA9)
ESPA9_close = ativo_ESPA9['close']
ESPA9_close.to_excel('ESPA9_close.xlsx')

# GRUPO SBF
SBFG3 = Ticker('SBFG3.SA')
hist_SBFG3 = SBFG3.history(period='60d', interval='5m')
ativo_SBFG3 = pd.DataFrame(hist_SBFG3)
SBFG3_close = ativo_SBFG3['close']
SBFG3_close.to_excel('SBFG3_close.xlsx')

# PETZ
PETZ3 = Ticker('PETZ3.SA')
hist_PETZ3 = PETZ3.history(period='60d', interval='5m')
ativo_PETZ3 = pd.DataFrame(hist_PETZ3)
PETZ3_close = ativo_PETZ3['close']
PETZ3_close.to_excel('PETZ3_close.xlsx')

# QUERO-QUERO
LJQQ3 = Ticker('LJQQ3.SA')
hist_LJQQ3 = LJQQ3.history(period='60d', interval='5m')
ativo_LJQQ3 = pd.DataFrame(hist_LJQQ3)
LJQQ3_close = ativo_LJQQ3['close']
LJQQ3_close.to_excel('LJQQ3_close.xlsx')

# SARAIVA LIVR
SLED3 = Ticker('SLED3.SA')
hist_SLED3 = SLED3.history(period='60d', interval='5m')
ativo_SLED3 = pd.DataFrame(hist_SLED3)
SLED3_close = ativo_SLED3['close']
SLED3_close.to_excel('SLED3_close.xlsx')

SLED4 = Ticker('SLED4.SA')
hist_SLED4 = SLED4.history(period='60d', interval='5m')
ativo_SLED4 = pd.DataFrame(hist_SLED4)
SLED4_close = ativo_SLED4['close']
SLED4_close.to_excel('SLED4_close.xlsx')
