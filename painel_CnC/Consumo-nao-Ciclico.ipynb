# %%
### SCRIPT PARA OBTER HISTORICO DE COTACAO DAS ACOES B3.
#
### ATE 15/09/2022 (site B3) 482 EMPRESAS COM ACOES NEGOCIAVEIS NO MERCADO A VISTA.
#
### CRITERIO DE SELECAO DOS TICKERS NEGOCIAVEIS.
### ATIVOS PERTENCENTES AOS SEGUIMENTOS NOVO MERCADO (NM),
### CIA. NIVEL 1 E 2 DE GOVERNANCA CORPORATIVA (N1 E N2),
### TRADICIONAL-BOLSA (EXCLUINDO DRE), BOVESPA MAIS (MA)
### E BOVESPA MAIS NIVEL 2 (M2).
 
###########################################################
# ROTINA PARA IMPORTAR O HISTORICO DE COTACAO DOS TICKERS #
###########################################################

# INSTALAR O YAHOO QUERY

# !pip install yahooquery

# (SE NECESSARIO) INSTALAR LEITOR DE ARQUIVO XLS

# !pip install xlrd

# INICIALIZAR OS MODULOS YAHOOQUERY

import yahooquery as yq
from yahooquery import Ticker

# INICIALIZAR OS MODULOS AUXILIARES

import pandas as pd
import requests as rq
import numpy as ny

###########################################################
# IMPORTAR HISTORICO DE COTACAO DOS ATIVOS SELECIONADOS   #
# OS CODIGOS SERAO DIVIDIDOS POR SETOR ECONOMICO          #
###########################################################

# %%
### 4 ###
############################################
### SETOR ECONOMICO: CONSUMO NAO CICLICO ###
############################################

# 3TENTOS
TTEN3 = Ticker('TTEN3.SA')
hist_TTEN3 = TTEN3.history(period='60d', interval='5m')
ativo_TTEN3 = pd.DataFrame(hist_TTEN3)
TTEN3_close = ativo_TTEN3['close']
TTEN3_close.to_excel('TTEN3_close.xlsx')

# AGROGALAXY
AGXY3 = Ticker('AGXY3.SA')
hist_AGXY3 = AGXY3.history(period='60d', interval='5m')
ativo_AGXY3 = pd.DataFrame(hist_AGXY3)
AGXY3_close = ativo_AGXY3['close']
AGXY3_close.to_excel('AGXY3_close.xlsx')

# BOA SAFRA
SOJA3 = Ticker('SOJA3.SA')
hist_SOJA3 = SOJA3.history(period='60d', interval='5m')
ativo_SOJA3 = pd.DataFrame(hist_SOJA3)
SOJA3_close = ativo_SOJA3['close']
SOJA3_close.to_excel('SOJA3_close.xlsx')

# BRASILAGRO
AGRO3 = Ticker('AGRO3.SA')
hist_AGRO3 = AGRO3.history(period='60d', interval='5m')
ativo_AGRO3 = pd.DataFrame(hist_AGRO3)
AGRO3_close = ativo_AGRO3['close']
AGRO3_close.to_excel('AGRO3_close.xlsx')

# POMIFRUTAS
FRTA3 = Ticker('FRTA3.SA')
hist_FRTA3 = FRTA3.history(period='60d', interval='5m')
ativo_FRTA3 = pd.DataFrame(hist_FRTA3)
FRTA3_close = ativo_FRTA3['close']
FRTA3_close.to_excel('FRTA3_close.xlsx')

# %%
# RAIZEN
RAIZ4 = Ticker('RAIZ4.SA')
hist_RAIZ4 = RAIZ4.history(period='60d', interval='5m')
ativo_RAIZ4 = pd.DataFrame(hist_RAIZ4)
RAIZ4_close = ativo_RAIZ4['close']
RAIZ4_close.to_excel('RAIZ4_close.xlsx')

# SLC AGRICOLA
SLCE3 = Ticker('SLCE3.SA')
hist_SLCE3 = SLCE3.history(period='60d', interval='5m')
ativo_SLCE3 = pd.DataFrame(hist_SLCE3)
SLCE3_close = ativo_SLCE3['close']
SLCE3_close.to_excel('SLCE3_close.xlsx')

# TERRASANTAPA
LAND3 = Ticker('LAND3.SA')
hist_LAND3 = LAND3.history(period='60d', interval='5m')
ativo_LAND3 = pd.DataFrame(hist_LAND3)
LAND3_close = ativo_LAND3['close']
LAND3_close.to_excel('LAND3_close.xlsx')

# JALLES MACHADO
JALL3 = Ticker('JALL3.SA')
hist_JALL3 = JALL3.history(period='60d', interval='5m')
ativo_JALL3 = pd.DataFrame(hist_JALL3)
JALL3_close = ativo_JALL3['close']
JALL3_close.to_excel('JALL3_close.xlsx')

# SAO MARTINHO
SMTO3 = Ticker('SMTO3.SA')
hist_SMTO3 = SMTO3.history(period='60d', interval='5m')
ativo_SMTO3 = pd.DataFrame(hist_SMTO3)
SMTO3_close = ativo_SMTO3['close']
SMTO3_close.to_excel('SMTO3_close.xlsx')

# %%
# BRF S.A.
BRFS3 = Ticker('BRFS3.SA')
hist_BRFS3 = BRFS3.history(period='60d', interval='5m')
ativo_BRFS3 = pd.DataFrame(hist_BRFS3)
BRFS3_close = ativo_BRFS3['close']
BRFS3_close.to_excel('BRFS3_close.xlsx')

# EXCELSIOR
BAUH3 = Ticker('BAUH3.SA')
hist_BAUH3 = BAUH3.history(period='60d', interval='5m')
ativo_BAUH3 = pd.DataFrame(hist_BAUH3)
BAUH3_close = ativo_BAUH3['close']
BAUH3_close.to_excel('BAUH3_close.xlsx')

BAUH4 = Ticker('BAUH4.SA')
hist_BAUH4 = BAUH4.history(period='60d', interval='5m')
ativo_BAUH4 = pd.DataFrame(hist_BAUH4)
BAUH4_close = ativo_BAUH4['close']
BAUH4_close.to_excel('BAUH4_close.xlsx')

# JBS
JBSS3 = Ticker('JBSS3.SA')
hist_JBSS3 = JBSS3.history(period='60d', interval='5m')
ativo_JBSS3 = pd.DataFrame(hist_JBSS3)
JBSS3_close = ativo_JBSS3['close']
JBSS3_close.to_excel('JBSS3_close.xlsx')

# MARFRIG
MRFG3 = Ticker('MRFG3.SA')
hist_MRFG3 = MRFG3.history(period='60d', interval='5m')
ativo_MRFG3 = pd.DataFrame(hist_MRFG3)
MRFG3_close = ativo_MRFG3['close']
MRFG3_close.to_excel('MRFG3_close.xlsx')

# %%
# MINERVA
BEEF3 = Ticker('BEEF3.SA')
hist_BEEF3 = BEEF3.history(period='60d', interval='5m')
ativo_BEEF3 = pd.DataFrame(hist_BEEF3)
BEEF3_close = ativo_BEEF3['close']
BEEF3_close.to_excel('BEEF3_close.xlsx')

# MINUPAR
MNPR3 = Ticker('MNPR3.SA')
hist_MNPR3 = MNPR3.history(period='60d', interval='5m')
ativo_MNPR3 = pd.DataFrame(hist_MNPR3)
MNPR3_close = ativo_MNPR3['close']
MNPR3_close.to_excel('MNPR3_close.xlsx')

# CAMIL
CAML3 = Ticker('CAML3.SA')
hist_CAML3 = CAML3.history(period='60d', interval='5m')
ativo_CAML3 = pd.DataFrame(hist_CAML3)
CAML3_close = ativo_CAML3['close']
CAML3_close.to_excel('CAML3_close.xlsx')

# JOSAPAR
JOPA3 = Ticker('JOPA3.SA')
hist_JOPA3 = JOPA3.history(period='60d', interval='5m')
ativo_JOPA3 = pd.DataFrame(hist_JOPA3)
JOPA3_close = ativo_JOPA3['close']
JOPA3_close.to_excel('JOPA3_close.xlsx')

JOPA4 = Ticker('JOPA4.SA')
hist_JOPA4 = JOPA4.history(period='60d', interval='5m')
ativo_JOPA4 = pd.DataFrame(hist_JOPA4)
JOPA4_close = ativo_JOPA4['close']
JOPA4_close.to_excel('JOPA4_close.xlsx')

# %%
# M. DIASBRANCO
MDIA3 = Ticker('MDIA3.SA')
hist_MDIA3 = MDIA3.history(period='60d', interval='5m')
ativo_MDIA3 = pd.DataFrame(hist_MDIA3)
MDIA3_close = ativo_MDIA3['close']
MDIA3_close.to_excel('MDIA3_close.xlsx')

# AMBEV S/A
ABEV3 = Ticker('ABEV3.SA')
hist_ABEV3 = ABEV3.history(period='60d', interval='5m')
ativo_ABEV3 = pd.DataFrame(hist_ABEV3)
ABEV3_close = ativo_ABEV3['close']
ABEV3_close.to_excel('ABEV3_close.xlsx')

# GRUPO NATURA
NTCO3 = Ticker('NTCO3.SA')
hist_NTCO3 = NTCO3.history(period='60d', interval='5m')
ativo_NTCO3 = pd.DataFrame(hist_NTCO3)
NTCO3_close = ativo_NTCO3['close']
NTCO3_close.to_excel('NTCO3_close.xlsx')

# BOMBRIL
BOBR4 = Ticker('BOBR4.SA')
hist_BOBR4 = BOBR4.history(period='60d', interval='5m')
ativo_BOBR4 = pd.DataFrame(hist_BOBR4)
BOBR4_close = ativo_BOBR4['close']
BOBR4_close.to_excel('BOBR4_close.xlsx')

# ASSAI
ASAI3 = Ticker('ASAI3.SA')
hist_ASAI3 = ASAI3.history(period='60d', interval='5m')
ativo_ASAI3 = pd.DataFrame(hist_ASAI3)
ASAI3_close = ativo_ASAI3['close']
ASAI3_close.to_excel('ASAI3_close.xlsx')

# %%
# CARREFOUR BR
CRFB3 = Ticker('CRFB3.SA')
hist_CRFB3 = CRFB3.history(period='60d', interval='5m')
ativo_CRFB3 = pd.DataFrame(hist_CRFB3)
CRFB3_close = ativo_CRFB3['close']
CRFB3_close.to_excel('CRFB3_close.xlsx')

# GRUPO MATEUS
GMAT3 = Ticker('GMAT3.SA')
hist_GMAT3 = GMAT3.history(period='60d', interval='5m')
ativo_GMAT3 = pd.DataFrame(hist_GMAT3)
GMAT3_close = ativo_GMAT3['close']
GMAT3_close.to_excel('GMAT3_close.xlsx')

# P. ACUCAR-CBD
PCAR3 = Ticker('PCAR3.SA')
hist_PCAR3 = PCAR3.history(period='60d', interval='5m')
ativo_PCAR3 = pd.DataFrame(hist_PCAR3)
PCAR3_close = ativo_PCAR3['close']
PCAR3_close.to_excel('PCAR3_close.xlsx')
